# %% [markdown]
# # BE - Benign Equivalized

# %%
import numpy as np
from numpy import genfromtxt, argmax
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import pandas as pd
import re
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score, precision_score, recall_score, mean_absolute_error, matthews_corrcoef, roc_curve, auc,RocCurveDisplay

import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, GaussianNoise
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

pd.set_option('display.max_columns', None)
plt.rcParams["figure.figsize"] = (27, 10)
# plt.rcParams["xtick.labelsize"] = 10
sns.set_context('paper', font_scale=2)

# %%
def calculate_classifications(y_p, y, a): #calculate correct and wrong classifications by attack category
    y_p = y_p.flatten()
    df= pd.DataFrame({'pred':y_p, 'label':y, 'attack':a})
    df['misclassification'] = df.apply(f, axis=1)
    df = df[df['attack']!='Benign']
    attacks = df['attack'].unique()
    att_dic_w = dict((n, 0) for n in attacks)
    att_dic_c = att_dic_w.copy()
    count_series = df.groupby(['attack', 'misclassification']).size()
    print(count_series)
    for key in attacks:
        counts = count_series.get(key).to_list()
        print(counts)
        if count_series.get(key).get(0) == None:
            counts.insert(0,0)
        elif count_series.get(key).get(1) == None:
            counts.insert(1,0)
        att_dic_w[key] = counts[1]
        att_dic_c[key] = counts[0]
    return att_dic_w, att_dic_c

def plot_roc_auc(y_true_oboa, y_true_rboa, y_pred_oboa, y_pred_rboa):
    ns_probs = [0 for _ in range(len(y_true_oboa))]
    
    #calculate fpr, tpr & thesholds for oboa, rboa, random
    fpr_oboa, tpr_oboa, thresholds_oboa = roc_curve(y_true_oboa, y_pred_oboa)
    fpr_rboa, tpr_rboa, thresholds_rboa = roc_curve(y_true_rboa, y_pred_rboa)
    fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_true_oboa, ns_probs)
    
    #auc calculation
    auc_oboa = auc(fpr_oboa, tpr_oboa)    
    auc_rboa = auc(fpr_rboa, tpr_rboa)
    auc_rand = auc(fpr_rand, tpr_rand)
    print('15_15_15: ROC AUC=%.3f' % (auc_oboa))
    print('10_5_10: ROC AUC=%.3f' % (auc_rboa))
    print('Random: ROC AUC=%.3f' % (auc_rand))
    
    #plot data
    plt.plot(fpr_oboa, tpr_oboa, marker='.', label='15_15_15')
    plt.plot(fpr_rboa, tpr_rboa, marker='.', label='10_5_10')
    plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()

def plot_attack_classifications(att_dic_w, att_dic_c): #plot correct and wrong classifications by attack category
    width = 0.4
    keys = att_dic_w.keys()
    values_w = att_dic_w.values()
    values_c = att_dic_c.values()
    x = np.arange(len(keys))
    fig, ax = plt.subplots()
    r1 = ax.bar(x - width/2, values_w, width, label = "Misclassified")
    r2 = ax.bar(x + width/2, values_c, width, label = "Correct Classification")
    ax.set_ylabel('Count')
    ax.set_xlabel('Attack')
    ax.set_title('Classification by Attack')
    ax.set_xticks(x)
    ax.set_xticklabels(keys)
    ax.legend()
    ax.bar_label(r1, padding=3)
    ax.bar_label(r2, padding=3)
    plt.xticks(rotation=45, ha='right')
    fig.tight_layout()
#     plt.rcParams["figure.figsize"] = (30, 10)
#     plt.rcParams["xtick.labelsize"] = 10
    plt.show()
    
#https://stackoverflow.com/questions/42528921/how-to-prevent-overlapping-x-axis-labels-in-sns-countplot
def attack_report(y, y_p, a):
    att_dic_w, att_dic_c = calculate_classifications(y_p, y, a)
    plot_attack_classifications(att_dic_w, att_dic_c)


def f(row):
    if row['pred'] != row['label']:
        val = 1
    else: val = 0
    return val
    
def print_cm(y_test,y_pred_round): #show confusion matrix
    cm = confusion_matrix(y_test,y_pred_round)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benign', 'Anomaly'])
    disp = disp.plot(include_values=True, cmap = 'Blues')
    print(cm)
#     plt.rcParams["figure.figsize"] = (30, 10)
    plt.show()
    
def print_metrics(y_test,y_pred_round): #print basic metrics
    f1 = f1_score(y_test, y_pred_round, average='binary')
    acc = accuracy_score(y_test, y_pred_round)
    prec = precision_score(y_test, y_pred_round, average='binary')
    recall = recall_score(y_test, y_pred_round, average = 'binary')
    mcc = matthews_corrcoef(y_test, y_pred_round)
    print('accuracy: ',acc)
    print('f1: ', f1)
    print('precision: ', prec)
    print('recall: ', recall)
    print('mcc: ', mcc)
    
def training_report(train_model): #plot acc and loss vs epochs
    loss_vals = train_model.history['loss']
    epochs = range(1, len(loss_vals)+1)
#     plt.rcParams["figure.figsize"] = (30, 10)
    validation_loss = train_model.history['val_loss']
    plt.plot(epochs, loss_vals, label='Training Loss')
    plt.plot(epochs, validation_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    acc_vals = train_model.history['binary_accuracy']
    validation_acc = train_model.history['val_binary_accuracy']
    plt.plot(epochs, acc_vals, label='Training Accuracy')
    plt.plot(epochs, validation_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    
def test_report(y_test,y_pred_round):
    print_cm(y_test,y_pred_round)
    print_metrics(y_test,y_pred_round)

# %% [markdown]
# # Data Index
#
# - X_train, y_train - Training data from 3 datasets
# - X_test, y_test - Test data from 3 datasets
# - X_val, y_val - Validation data from 3 datasets
# - X_1, y_1 - 1 datasets, test phase 2 data

# %%
folder_rboa = 'rboa\\'
name_tail = '_rboa'
dnnfolder = 'E2_DNN\\'

NNs = [[32, 32], [10, 25, 15, 10]]

# %%
X_train = np.load(folder_rboa+'X_train.npy')
X_val = np.load(folder_rboa+'X_val.npy')
y_train = np.load(folder_rboa+'y_train.npy')
y_val = np.load(folder_rboa+'y_val.npy')

# %%
batch_sz = 256
lr = 1e-4
esp = 10
rlrp = 5

dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail+".h5"
print(dnn_file)

weights = {0:1, 1:5}
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=rlrp, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
es = EarlyStopping(monitor='val_loss', patience=esp, mode='auto', restore_best_weights=False, min_delta=0.0001)
opt = Adam(learning_rate=lr)

DNN = Sequential()
for c in range(0,len(NNs[0])):
    if c == 0:
        DNN.add(Dense(NNs[0][0], input_dim=len(X_train[0]), activation='relu'))
        DNN.add(Dropout(0.5))
    else:
        DNN.add(Dense(NNs[0][c], activation='relu'))
        DNN.add(Dropout(0.5))
DNN.add(Dense(1, activation='sigmoid'))
DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
DNN.summary()
train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
DNN.save(dnnfolder+dnn_file)
training_report(train_DNN)
# Out:
# DNN_32_32_rboa.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                288
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,377
# Trainable params: 1,377
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Will\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 28262/28262 [==============================] - 51s 2ms/step - loss: 0.7385 - binary_accuracy: 0.8348 - precision: 0.5628 - recall: 0.7802 - auc: 0.8916 - val_loss: 0.2787 - val_binary_accuracy: 0.9203 - val_precision: 0.7920 - val_recall: 0.8153 - val_auc: 0.9536
# Epoch 2/100
# 28262/28262 [==============================] - 60s 2ms/step - loss: 0.5461 - binary_accuracy: 0.8791 - precision: 0.6574 - recall: 0.8258 - auc: 0.9401 - val_loss: 0.2349 - val_binary_accuracy: 0.9296 - val_precision: 0.8279 - val_recall: 0.8184 - val_auc: 0.9593ecall - ETA
# Epoch 3/100
# 28262/28262 [==============================] - 53s 2ms/step - loss: 0.4940 - binary_accuracy: 0.8973 - precision: 0.7106 - recall: 0.8206 - auc: 0.9480 - val_loss: 0.2275 - val_binary_accuracy: 0.9296 - val_precision: 0.8304 - val_recall: 0.8141 - val_auc: 0.9604
# Epoch 4/100
# 28262/28262 [==============================] - 49s 2ms/step - loss: 0.4698 - binary_accuracy: 0.9171 - precision: 0.7866 - recall: 0.8035 - auc: 0.9512 - val_loss: 0.2224 - val_binary_accuracy: 0.9450 - val_precision: 0.9020 - val_recall: 0.8134 - val_auc: 0.9624
# Epoch 5/100
# 28262/28262 [==============================] - 49s 2ms/step - loss: 0.4597 - binary_accuracy: 0.9205 - precision: 0.8003 - recall: 0.8029 - auc: 0.9525 - val_loss: 0.2200 - val_binary_accuracy: 0.9431 - val_precision: 0.8917 - val_recall: 0.8146 - val_auc: 0.9628
# Epoch 6/100
# 28262/28262 [==============================] - 50s 2ms/step - loss: 0.4521 - binary_accuracy: 0.9231 - precision: 0.8104 - recall: 0.8033 - auc: 0.9535 - val_loss: 0.2168 - val_binary_accuracy: 0.9465 - val_precision: 0.9077 - val_recall: 0.8153 - val_auc: 0.9630ccuracy: 0.9224 - pre - ETA: 11s - loss: 0.4530 - binary_accuracy: 0.9226  - ETA: 1s - loss: 0.4522 - binary
# Epoch 7/100
# 28262/28262 [==============================] - 49s 2ms/step - loss: 0.4468 - binary_accuracy: 0.9256 - precision: 0.8207 - recall: 0.8036 - auc: 0.9540 - val_loss: 0.2154 - val_binary_accuracy: 0.9488 - val_precision: 0.9207 - val_recall: 0.8143 - val_auc: 0.9632: 0.4517 - binary_accuracy: 0.9237 - precision: 0.8138 - recall: 0.8026 - au - ETA: 41s - loss: 0.4515 - binary_accuracy: 0.9238 - precision: 0.8144 - recall: 0.8026  - ETA: 42s - loss: 0.4502 - binary_accuracy:
# Epoch 8/100
# 28262/28262 [==============================] - 46s 2ms/step - loss: 0.4433 - binary_accuracy: 0.9276 - precision: 0.8296 - recall: 0.8028 - auc: 0.9543 - val_loss: 0.2176 - val_binary_accuracy: 0.9494 - val_precision: 0.9222 - val_recall: 0.8160 - val_auc: 0.9632
# Epoch 9/100
# 28262/28262 [==============================] - 50s 2ms/step - loss: 0.4417 - binary_accuracy: 0.9288 - precision: 0.8349 - recall: 0.8030 - auc: 0.9545 - val_loss: 0.2148 - val_binary_accuracy: 0.9504 - val_precision: 0.9273 - val_recall: 0.8158 - val_auc: 0.9633
# Epoch 10/100
# 28262/28262 [==============================] - 47s 2ms/step - loss: 0.4388 - binary_accuracy: 0.9301 - precision: 0.8401 - recall: 0.8034 - auc: 0.9547 - val_loss: 0.2164 - val_binary_accuracy: 0.9512 - val_precision: 0.9305 - val_recall: 0.8169 - val_auc: 0.9632
# Epoch 11/100
# 28262/28262 [==============================] - 51s 2ms/step - loss: 0.4382 - binary_accuracy: 0.9306 - precision: 0.8426 - recall: 0.8030 - auc: 0.9549 - val_loss: 0.2155 - val_binary_accuracy: 0.9510 - val_precision: 0.9293 - val_recall: 0.8173 - val_auc: 0.9654
# Epoch 12/100
# 28262/28262 [==============================] - 57s 2ms/step - loss: 0.4360 - binary_accuracy: 0.9309 - precision: 0.8435 - recall: 0.8036 - auc: 0.9551 - val_loss: 0.2160 - val_binary_accuracy: 0.9510 - val_precision: 0.9291 - val_recall: 0.8172 - val_auc: 0.9634 binary_accuracy: 0.9310 - precision: 0.8436 - re - ETA: 5s - loss: 0.4356 - binary_accuracy: 0.9310 - precision: - ETA: 4s -
# Epoch 13/100
# 28262/28262 [==============================] - 53s 2ms/step - loss: 0.4349 - binary_accuracy: 0.9312 - precision: 0.8450 - recall: 0.8035 - auc: 0.9551 - val_loss: 0.2160 - val_binary_accuracy: 0.9510 - val_precision: 0.9292 - val_recall: 0.8172 - val_auc: 0.9636 - loss: 0.4348 - binary_accuracy: 0.9313 - prec
# Epoch 14/100
# 28262/28262 [==============================] - 54s 2ms/step - loss: 0.4345 - binary_accuracy: 0.9319 - precision: 0.8483 - recall: 0.8033 - auc: 0.9552 - val_loss: 0.2153 - val_binary_accuracy: 0.9521 - val_precision: 0.9355 - val_recall: 0.8167 - val_auc: 0.9635316 - precision: 0.8464 - reca - ETA: 33s - loss: 0.4348 - binary_accuracy: 0.9316 - prec
# Epoch 15/100
# 28262/28262 [==============================] - 54s 2ms/step - loss: 0.4323 - binary_accuracy: 0.9321 - precision: 0.8489 - recall: 0.8036 - auc: 0.9554 - val_loss: 0.2140 - val_binary_accuracy: 0.9521 - val_precision: 0.9360 - val_recall: 0.8165 - val_auc: 0.9636
# Epoch 16/100
# 28262/28262 [==============================] - 55s 2ms/step - loss: 0.4315 - binary_accuracy: 0.9322 - precision: 0.8493 - recall: 0.8037 - auc: 0.9555 - val_loss: 0.2139 - val_binary_accuracy: 0.9521 - val_precision: 0.9356 - val_recall: 0.8165 - val_auc: 0.963916 - binary_a - ETA: 34s -  - ETA: 29s - loss: 0.4314 - bin
# Epoch 17/100
# 28262/28262 [==============================] - 49s 2ms/step - loss: 0.4319 - binary_accuracy: 0.9325 - precision: 0.8507 - recall: 0.8034 - auc: 0.9555 - val_loss: 0.2145 - val_binary_accuracy: 0.9521 - val_precision: 0.9356 - val_recall: 0.8165 - val_auc: 0.9636
# Epoch 18/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4326 - binary_accuracy: 0.9324 - precision: 0.8507 - recall: 0.8026 - auc: 0.9553 - val_loss: 0.2141 - val_binary_accuracy: 0.9521 - val_precision: 0.9359 - val_recall: 0.8165 - val_auc: 0.9654
# Epoch 19/100
# 28262/28262 [==============================] - 47s 2ms/step - loss: 0.4318 - binary_accuracy: 0.9326 - precision: 0.8514 - recall: 0.8030 - auc: 0.9554 - val_loss: 0.2138 - val_binary_accuracy: 0.9521 - val_precision: 0.9358 - val_recall: 0.8165 - val_auc: 0.9616
# Epoch 20/100
# 28262/28262 [==============================] - 46s 2ms/step - loss: 0.4317 - binary_accuracy: 0.9325 - precision: 0.8512 - recall: 0.8031 - auc: 0.9554 - val_loss: 0.2140 - val_binary_accuracy: 0.9521 - val_precision: 0.9356 - val_recall: 0.8165 - val_auc: 0.9662
# Epoch 21/100
# 28262/28262 [==============================] - 46s 2ms/step - loss: 0.4321 - binary_accuracy: 0.9324 - precision: 0.8509 - recall: 0.8029 - auc: 0.9554 - val_loss: 0.2136 - val_binary_accuracy: 0.9521 - val_precision: 0.9356 - val_recall: 0.8165 - val_auc: 0.9635
# Epoch 22/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4319 - binary_accuracy: 0.9327 - precision: 0.8520 - recall: 0.8029 - auc: 0.9555 - val_loss: 0.2137 - val_binary_accuracy: 0.9520 - val_precision: 0.9355 - val_recall: 0.8165 - val_auc: 0.9639racy: 0.9326 - precision:
# Epoch 23/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4315 - binary_accuracy: 0.9326 - precision: 0.8516 - recall: 0.8028 - auc: 0.9555 - val_loss: 0.2136 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9640
# Epoch 24/100
# 28262/28262 [==============================] - 47s 2ms/step - loss: 0.4310 - binary_accuracy: 0.9327 - precision: 0.8519 - recall: 0.8029 - auc: 0.9555 - val_loss: 0.2140 - val_binary_accuracy: 0.9520 - val_precision: 0.9355 - val_recall: 0.8164 - val_auc: 0.9636
# Epoch 25/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4321 - binary_accuracy: 0.9327 - precision: 0.8525 - recall: 0.8024 - auc: 0.9553 - val_loss: 0.2139 - val_binary_accuracy: 0.9520 - val_precision: 0.9355 - val_recall: 0.8165 - val_auc: 0.966920 - binary_accuracy: 0.9327 - precision: - ETA: 3s - loss: 0.4319 - bi - ETA: 1s - loss: 0.4321 - binary_accuracy: 0.932 - ETA: 0s - loss: 0.4320 - binary_accuracy: 0.9327 - precision: 0.8524 - recall: 0.8024 - auc
# Epoch 26/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4313 - binary_accuracy: 0.9329 - precision: 0.8528 - recall: 0.8030 - auc: 0.9554 - val_loss: 0.2136 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9639
# Epoch 27/100
# 28262/28262 [==============================] - 48s 2ms/step - loss: 0.4308 - binary_accuracy: 0.9329 - precision: 0.8529 - recall: 0.8030 - auc: 0.9556 - val_loss: 0.2136 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9639
# Epoch 28/100
# 28262/28262 [==============================] - 47s 2ms/step - loss: 0.4312 - binary_accuracy: 0.9330 - precision: 0.8534 - recall: 0.8027 - auc: 0.9555 - val_loss: 0.2137 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9639
# Epoch 29/100
# 28262/28262 [==============================] - 51s 2ms/step - loss: 0.4305 - binary_accuracy: 0.9330 - precision: 0.8537 - recall: 0.8028 - auc: 0.9555 - val_loss: 0.2137 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9639
# Epoch 30/100
# 28262/28262 [==============================] - 59s 2ms/step - loss: 0.4310 - binary_accuracy: 0.9329 - precision: 0.8532 - recall: 0.8026 - auc: 0.9555 - val_loss: 0.2136 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9639
# Epoch 31/100
# 28262/28262 [==============================] - 56s 2ms/step - loss: 0.4307 - binary_accuracy: 0.9331 - precision: 0.8542 - recall: 0.8027 - auc: 0.9556 - val_loss: 0.2137 - val_binary_accuracy: 0.9521 - val_precision: 0.9357 - val_recall: 0.8164 - val_auc: 0.9641racy: 0.9335 - precision: 0.8554 - recall:  - ETA: 50s - loss: 0.4310 - binary_accuracy: 0.9336 - precision: 0.8552 - recall: 0.8033 - auc:  - ETA: 51s - loss:  - ETA:  - ETA: 20s - loss: 0.4304 - binary_accuracy: 0.9331 - precision: 0.8540 - r - ETA: - ETA: 0s - loss: 0.4307 - binary_accuracy: 0.9331 - precision: 0.8542 - recall:  - ETA: 0s - loss: 0.4307 - binary_accuracy: 0.9331 - precision: 0.8542 - recall: 0.80 - ETA: 0s - loss: 0.4307 - binary_accuracy: 0.9331 - precision: 0.8542 - recall: 0.8028 - auc:

# %%
batch_sz = 256
lr = 1e-4
esp = 10
rlrp = 5

dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail+".h5"
print(dnn_file)

weights = {0:1, 1:5}
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=rlrp, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
es = EarlyStopping(monitor='val_loss', patience=esp, mode='auto', restore_best_weights=False, min_delta=0.0001)
opt = Adam(learning_rate=lr)

DNN = Sequential()
for c in range(0,len(NNs[1])):
    if c == 0:
        DNN.add(Dense(NNs[1][0], input_dim=len(X_train[0]), activation='relu'))
        DNN.add(Dropout(0.5))
    else:
        DNN.add(Dense(NNs[1][c], activation='relu'))
        DNN.add(Dropout(0.5))
DNN.add(Dense(1, activation='sigmoid'))
DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
DNN.summary()
train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
DNN.save(dnnfolder+dnn_file)
training_report(train_DNN)
# Out:
# DNN_10_25_15_10_rboa.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                90
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                275
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                390
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 926
# Trainable params: 926
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 28262/28262 [==============================] - 61s 2ms/step - loss: 1.0102 - binary_accuracy: 0.7635 - precision: 0.4414 - recall: 0.6871 - auc: 0.7974 - val_loss: 0.4345 - val_binary_accuracy: 0.9256 - val_precision: 0.8312 - val_recall: 0.7878 - val_auc: 0.9349s: 1.2521 - binary_accuracy: 0.2952 - precision: 0.1839 - recal - ETA: 53 - ETA: 1s - loss: 1.0139 - binary_accuracy: 0
# Epoch 2/100
# 28262/28262 [==============================] - 57s 2ms/step - loss: 0.8584 - binary_accuracy: 0.8811 - precision: 0.7099 - recall: 0.6856 - auc: 0.8657 - val_loss: 0.4011 - val_binary_accuracy: 0.9234 - val_precision: 0.8277 - val_recall: 0.7791 - val_auc: 0.9404TA:
# Epoch 3/100
# 28262/28262 [==============================] - 57s 2ms/step - loss: 0.8241 - binary_accuracy: 0.8870 - precision: 0.7285 - recall: 0.6934 - auc: 0.8729 - val_loss: 0.3884 - val_binary_accuracy: 0.9234 - val_precision: 0.8331 - val_recall: 0.7719 - val_auc: 0.9416- ETA: 4s - loss: 0.8246 - binary_accuracy: 0.8868 - precision: 0.7280 - recall: 0. - ETA: 4s - loss: 0.8246 - binary_accuracy: 0.8868 - precision: 0.7281 - recall: 0.6931 - auc: 0. - ETA: 4s - loss: 0.8246 - binary_acc - ETA: 0s - loss: 0.8242 - binary_accuracy: 0.8870 - precision: 0.7285 - recall: 0.6934 - auc
# Epoch 4/100
# 28262/28262 [==============================] - 62s 2ms/step - loss: 0.8098 - binary_accuracy: 0.8890 - precision: 0.7347 - recall: 0.6963 - auc: 0.8745 - val_loss: 0.3782 - val_binary_accuracy: 0.9274 - val_precision: 0.8445 - val_recall: 0.7804 - val_auc: 0.9437c - ETA: 15s - loss: 0.8101 - binary_accuracy: 0.8886 - precision: 0.7335 - recall: 0.6961 - - ETA: 2s - loss: 0.809
# Epoch 5/100
# 28262/28262 [==============================] - 56s 2ms/step - loss: 0.8058 - binary_accuracy: 0.8919 - precision: 0.7452 - recall: 0.6984 - auc: 0.8755 - val_loss: 0.3792 - val_binary_accuracy: 0.9275 - val_precision: 0.8461 - val_recall: 0.7792 - val_auc: 0.9457.8077 - binary_accuracy: 0.8922 - precision:  - ETA: 15s - loss: 0.8075 - bin - ETA: 11s - loss: 0.8070 - binary - ETA: 9s - loss: 0.8070 - binary_accuracy: 0.8920 - precision: 0.7457  - ETA: 8s - loss: 0.8068 - binary_a - ETA - ETA: 1s - loss: 0.8060 - binary_accuracy: 0.8920 - precision: 0.7453 - recall: 0.6983 - auc: 0. - ETA: 1s - loss:
# Epoch 6/100
# 28262/28262 [==============================] - 57s 2ms/step - loss: 0.8015 - binary_accuracy: 0.8907 - precision: 0.7392 - recall: 0.7003 - auc: 0.8778 - val_loss: 0.3774 - val_binary_accuracy: 0.9273 - val_precision: 0.8456 - val_recall: 0.7785 - val_auc: 0.9490ar - ETA: 21s - loss: 0.8012 - binary_accuracy: 0.8907 - precision: 0.739 - ETA: 19s - loss: 0.8013 - binary_accuracy: 0.8907 - precision: 0.7389 - re - ETA: 17s - loss: 0.8011 - binary_accuracy: 0.8906 - precision: 0.7389 - recall: 0. - ETA: 16s - loss: 0.8009 - binary_accuracy: 0.8907 - precision: 0.7389 - recall: 0.7001 -  - ETA: 16s - loss: 0.8008 - binary_accur - ETA - ETA: 6s - loss: 0.8016 - binary_accuracy: 0.8907 - precisio - ETA: 5s - loss: - ETA: 3s - loss: 0.8014 - binary_accuracy: 0.8907 - prec - ETA:  - ETA: 0s - loss: 0.8015 - binary_accuracy: 0.8907 - precision: 0.7392 - recall: 0.7003 - auc: 0.87
# Epoch 7/100
# 28262/28262 [==============================] - 52s 2ms/step - loss: 0.7990 - binary_accuracy: 0.8911 - precision: 0.7405 - recall: 0.7010 - auc: 0.8779 - val_loss: 0.3781 - val_binary_accuracy: 0.9260 - val_precision: 0.8482 - val_recall: 0.7674 - val_auc: 0.9520
# Epoch 8/100
# 28262/28262 [==============================] - 54s 2ms/step - loss: 0.7978 - binary_accuracy: 0.8908 - precision: 0.7391 - recall: 0.7014 - auc: 0.8781 - val_loss: 0.3769 - val_binary_accuracy: 0.9255 - val_precision: 0.8475 - val_recall: 0.7652 - val_auc: 0.9504
# Epoch 9/100
# 28262/28262 [==============================] - 60s 2ms/step - loss: 0.7975 - binary_accuracy: 0.8914 - precision: 0.7415 - recall: 0.7012 - auc: 0.8783 - val_loss: 0.3767 - val_binary_accuracy: 0.9251 - val_precision: 0.8486 - val_recall: 0.7613 - val_auc: 0.9527
# Epoch 10/100
# 28262/28262 [==============================] - 53s 2ms/step - loss: 0.7972 - binary_accuracy: 0.8938 - precision: 0.7515 - recall: 0.7004 - auc: 0.8804 - val_loss: 0.3730 - val_binary_accuracy: 0.9243 - val_precision: 0.8494 - val_recall: 0.7555 - val_auc: 0.9520
# Epoch 11/100
# 28262/28262 [==============================] - 54s 2ms/step - loss: 0.7973 - binary_accuracy: 0.8956 - precision: 0.7593 - recall: 0.6998 - auc: 0.8801 - val_loss: 0.3724 - val_binary_accuracy: 0.9245 - val_precision: 0.8526 - val_recall: 0.7524 - val_auc: 0.9498
# Epoch 12/100
# 28262/28262 [==============================] - 56s 2ms/step - loss: 0.7962 - binary_accuracy: 0.8956 - precision: 0.7586 - recall: 0.7008 - auc: 0.8797 - val_loss: 0.3706 - val_binary_accuracy: 0.9267 - val_precision: 0.8598 - val_recall: 0.7571 - val_auc: 0.9458 recall: 0.7005 - a - ETA: 12s - loss: 0.7968 - binary_accuracy: 0.8954 - precision: 0.7586 - recall: 0.7005 - auc:  - ETA: 12s - loss: 0.7968 - binary_accuracy: 0.8954 - precision: 0.7586 - ETA: 10s - loss: 0.7967 - b
# Epoch 13/100
# 28262/28262 [==============================] - 53s 2ms/step - loss: 0.7951 - binary_accuracy: 0.8960 - precision: 0.7600 - recall: 0.7017 - auc: 0.8796 - val_loss: 0.3709 - val_binary_accuracy: 0.9321 - val_precision: 0.8821 - val_recall: 0.7624 - val_auc: 0.9509inary_accuracy: 0.8960 - precision: 0.7601 - recall
# Epoch 14/100
# 28262/28262 [==============================] - 59s 2ms/step - loss: 0.7944 - binary_accuracy: 0.8960 - precision: 0.7598 - recall: 0.7020 - auc: 0.8806 - val_loss: 0.3673 - val_binary_accuracy: 0.9318 - val_precision: 0.8870 - val_recall: 0.7553 - val_auc: 0.9505
# Epoch 15/100
# 28262/28262 [==============================] - 52s 2ms/step - loss: 0.7932 - binary_accuracy: 0.8943 - precision: 0.7524 - recall: 0.7031 - auc: 0.8828 - val_loss: 0.3707 - val_binary_accuracy: 0.9314 - val_precision: 0.8814 - val_recall: 0.7590 - val_auc: 0.9511
# Epoch 16/100
# 28262/28262 [==============================] - 49s 2ms/step - loss: 0.7936 - binary_accuracy: 0.8936 - precision: 0.7492 - recall: 0.7031 - auc: 0.8820 - val_loss: 0.3723 - val_binary_accuracy: 0.9311 - val_precision: 0.8810 - val_recall: 0.7577 - val_auc: 0.9537
# Epoch 17/100
# 28262/28262 [==============================] - 55s 2ms/step - loss: 0.7922 - binary_accuracy: 0.8942 - precision: 0.7517 - recall: 0.7030 - auc: 0.8829 - val_loss: 0.3708 - val_binary_accuracy: 0.9313 - val_precision: 0.8771 - val_recall: 0.7633 - val_auc: 0.9530
# Epoch 18/100
# 28262/28262 [==============================] - 60s 2ms/step - loss: 0.7913 - binary_accuracy: 0.8950 - precision: 0.7552 - recall: 0.7030 - auc: 0.8842 - val_loss: 0.3704 - val_binary_accuracy: 0.9328 - val_precision: 0.8768 - val_recall: 0.7724 - val_auc: 0.95268950 - precisio - ETA: 3s - loss: 0.7913 - binary_a - ETA: 2s - loss: 0.7913 - bina - ETA: 1s - loss: 0.7912 - binary
# Epoch 19/100
# 28262/28262 [==============================] - 58s 2ms/step - loss: 0.7919 - binary_accuracy: 0.8951 - precision: 0.7551 - recall: 0.7034 - auc: 0.8844 - val_loss: 0.3728 - val_binary_accuracy: 0.9338 - val_precision: 0.8830 - val_recall: 0.7710 - val_auc: 0.9516: 40s - loss: 0.7913 - binary_accuracy: 0.8951 - precision: 0.7549 - recall: 0.7032 - au - ETA: 40s - loss: 0.7913 - binary_accurac - E - ETA: 5s - loss: 0.7913 - binary_accuracy: 0.8950 - precision: 0.7548 - reca
# Epoch 20/100
# 28262/28262 [==============================] - 54s 2ms/step - loss: 0.7890 - binary_accuracy: 0.8951 - precision: 0.7552 - recall: 0.7036 - auc: 0.8875 - val_loss: 0.3698 - val_binary_accuracy: 0.9341 - val_precision: 0.8847 - val_recall: 0.7708 - val_auc: 0.9527
# Epoch 21/100
# 28262/28262 [==============================] - 58s 2ms/step - loss: 0.7882 - binary_accuracy: 0.8955 - precision: 0.7568 - recall: 0.7039 - auc: 0.8877 - val_loss: 0.3687 - val_binary_accuracy: 0.9341 - val_precision: 0.8844 - val_recall: 0.7711 - val_auc: 0.9529
# Epoch 22/100
# 28262/28262 [==============================] - 59s 2ms/step - loss: 0.7890 - binary_accuracy: 0.8957 - precision: 0.7574 - recall: 0.7038 - auc: 0.8875 - val_loss: 0.3687 - val_binary_accuracy: 0.9340 - val_precision: 0.8846 - val_recall: 0.7703 - val_auc: 0.9528
# Epoch 23/100
# 28262/28262 [==============================] - 59s 2ms/step - loss: 0.7900 - binary_accuracy: 0.8955 - precision: 0.7567 - recall: 0.7036 - auc: 0.8875 - val_loss: 0.3689 - val_binary_accuracy: 0.9339 - val_precision: 0.8846 - val_recall: 0.7702 - val_auc: 0.9530
# Epoch 24/100
# 28262/28262 [==============================] - 57s 2ms/step - loss: 0.7894 - binary_accuracy: 0.8952 - precision: 0.7558 - recall: 0.7035 - auc: 0.8873 - val_loss: 0.3690 - val_binary_accuracy: 0.9339 - val_precision: 0.8842 - val_recall: 0.7705 - val_auc: 0.9527ss: 0.7 - ETA: 32s - loss: 0.7898 - binary_accuracy: 0.8954 - precision: 0.7564 - reca - ETA: 30s - loss: 0.7899 - binary_ac - ETA: 26s - loss: 0.7894 -

# %% [markdown]
# # Test Set

# %%
X_1 = np.load(folder_rboa +'X_test.npy')
y_1 = np.load(folder_rboa +'y_test.npy')

print('-----------------------------------------\n\n')
dnn_file_1 = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail+".h5"
dnn_file_2 = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail+".h5"

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.rint(y_pred_1)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.rint(y_pred_2)


ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_1))
test_report(y_1 ,y_predr_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
test_report(y_1 ,y_predr_2)
# Out:
# -----------------------------------------
#
#
# DNN_32_32_rboa.h5  ROC AUC=0.992
# DNN_10_25_15_10_rboa.h5 ROC AUC=0.977
# Random: ROC AUC=0.500
# DNN_32_32_rboa.h5
#
# Best Threshold=0.602309
# [[1888345   26663]
#  [  28269  450483]]
# accuracy:  0.9770520018715326
# f1:  0.9425336176035517
# precision:  0.9441198291508259
# recall:  0.9409527270904351
# mcc:  0.9281992261001025
# DNN_10_25_15_10_rboa.h5
#
# Best Threshold=0.512378
# [[1867218   47790]
#  [  37523  441229]]
# accuracy:  0.9643602533253125
# f1:  0.9118458808953771
# precision:  0.9022737357853171
# recall:  0.9216233039235345
# mcc:  0.8895929588623346

# %% [markdown]
# # Full Test Set (Benign Equalized)

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)


DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.rint(y_pred_1)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.rint(y_pred_2)


ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_1))
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)
# Out:
# DNN_32_32_rboa.h5  ROC AUC=0.456
# DNN_10_25_15_10_rboa.h5 ROC AUC=0.490
# Random: ROC AUC=0.500
# DNN_32_32_rboa.h5
#
# Best Threshold=0.991263
# [[9879369  141480]
#  [1625717  632424]]
# accuracy:  0.8560796124111185
# f1:  0.41716003555356207
# precision:  0.8171866277987968
# recall:  0.28006399954652966
# mcc:  0.4239667980867367
# attack                    misclassification
# Bot                       0                       8684
#                           1                     134413
# Brute Force -Web          0                          3
#                           1                       2140
# Brute Force -XSS          0                          2
#                           1                        925
# DDOS attack-HOIC          1                    1080858
# DDOS attack-LOIC-UDP      0                         15
#                           1                       2097
# DDoS attacks-LOIC-HTTP    0                      10500
#                           1                     296800
# DoS attacks-GoldenEye     0                      27723
# DoS attacks-Hulk          0                     432648
# DoS attacks-SlowHTTPTest  0                      14116
# DoS attacks-Slowloris     0                       9512
# FTP-BruteForce            0                      25933
# Infilteration             0                      17523
#                           1                      98838
# SQL Injection             1                        432
# SSH-Bruteforce            0                      94979
# dtype: int64
# [94979]
# [10500, 296800]
# [1080858]
# [9512]
# [432648]
# [25933]
# [17523, 98838]
# [8684, 134413]
# [27723]
# [3, 2140]
# [14116]
# [432]
# [15, 2097]
# [2, 925]
# DNN_10_25_15_10_rboa.h5
#
# Best Threshold=0.449738
# [[9766305  254544]
#  [1616503  641638]]
# accuracy:  0.8476220764085646
# f1:  0.4068308793994781
# precision:  0.7159684082027981
# recall:  0.28414434705361624
# mcc:  0.3853660271982516

# %%
# Full AR Test set threshold

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)

#test set thresholds
bt1 = 0.56
bt2 = 0.57

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.where(y_pred_1 > bt1, 1, 0)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.where(y_pred_2 > bt2, 1, 0)

ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_1))
print('Using test set threshold', bt1)
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
print('Using test set threshold', bt2)
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)

#test set thresholds
bt1 = best_thresh_1
bt2 = best_thresh_2

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.where(y_pred_1 > bt1, 1, 0)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.where(y_pred_2 > bt2, 1, 0)

ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_1))
print('Using test set threshold', bt1)
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
print('Using test set threshold', bt2)
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)

# %% [markdown]
# # AR Test Set (Benign Equalized)

# %%
X_1 = np.load(folder_rboa +'X_1_ar.npy')
y_1 = np.load(folder_rboa +'y_1_ar.npy')
a_1 = np.load(folder_rboa +'a_1_ar.npy', allow_pickle=True)



print('-----------------------------------------\n\n')
dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail_rboa+".h5"
dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail_rboa+".h5"

print(dnn_file_oboa, '\n')
DNN = load_model(dnnfolder+dnn_file_oboa)
y_pred_oboa = DNN.predict(X_1)
y_predr_oboa = np.rint(y_pred_oboa)
print(dnn_file_rboa, '\n')
DNN = load_model(dnnfolder+dnn_file_rboa)
y_pred_rboa = DNN.predict(X_1)
y_predr_rboa = np.rint(y_pred_rboa)

plot_roc_auc(y_1, y_1, y_pred_oboa, y_pred_rboa)

print('OBOA')
test_report(y_1 ,y_predr_oboa)
attack_report(y_1, y_predr_oboa, a_1)

print('RBOA')
test_report(y_1,y_predr_rboa)
attack_report(y_1, y_predr_rboa, a_1)
