# %% [markdown]
# # BE - Benign Equivalized

# %%
import numpy as np
from numpy import genfromtxt, argmax
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import pandas as pd
import re
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score, precision_score, recall_score, mean_absolute_error, matthews_corrcoef, roc_curve, auc,RocCurveDisplay

import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, GaussianNoise
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

pd.set_option('display.max_columns', None)
plt.rcParams["figure.figsize"] = (27, 10)
# plt.rcParams["xtick.labelsize"] = 10
sns.set_context('paper', font_scale=2)

# %%
def calculate_classifications(y_p, y, a): #calculate correct and wrong classifications by attack category
    y_p = y_p.flatten()
    df= pd.DataFrame({'pred':y_p, 'label':y, 'attack':a})
    df['misclassification'] = df.apply(f, axis=1)
    df = df[df['attack']!='Benign']
    attacks = df['attack'].unique()
    att_dic_w = dict((n, 0) for n in attacks)
    att_dic_c = att_dic_w.copy()
    count_series = df.groupby(['attack', 'misclassification']).size()
    print(count_series)
    for key in attacks:
        counts = count_series.get(key).to_list()
        print(counts)
        if count_series.get(key).get(0) == None:
            counts.insert(0,0)
        elif count_series.get(key).get(1) == None:
            counts.insert(1,0)
        att_dic_w[key] = counts[1]
        att_dic_c[key] = counts[0]
    return att_dic_w, att_dic_c

def plot_roc_auc(y_true_oboa, y_true_rboa, y_pred_oboa, y_pred_rboa):
    ns_probs = [0 for _ in range(len(y_true_oboa))]
    
    #calculate fpr, tpr & thesholds for oboa, rboa, random
    fpr_oboa, tpr_oboa, thresholds_oboa = roc_curve(y_true_oboa, y_pred_oboa)
    fpr_rboa, tpr_rboa, thresholds_rboa = roc_curve(y_true_rboa, y_pred_rboa)
    fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_true_oboa, ns_probs)
    
    #auc calculation
    auc_oboa = auc(fpr_oboa, tpr_oboa)    
    auc_rboa = auc(fpr_rboa, tpr_rboa)
    auc_rand = auc(fpr_rand, tpr_rand)
    print('15_15_15: ROC AUC=%.3f' % (auc_oboa))
    print('10_5_10: ROC AUC=%.3f' % (auc_rboa))
    print('Random: ROC AUC=%.3f' % (auc_rand))
    
    #plot data
    plt.plot(fpr_oboa, tpr_oboa, marker='.', label='15_15_15')
    plt.plot(fpr_rboa, tpr_rboa, marker='.', label='10_5_10')
    plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()

def plot_attack_classifications(att_dic_w, att_dic_c): #plot correct and wrong classifications by attack category
    width = 0.4
    keys = att_dic_w.keys()
    values_w = att_dic_w.values()
    values_c = att_dic_c.values()
    x = np.arange(len(keys))
    fig, ax = plt.subplots()
    r1 = ax.bar(x - width/2, values_w, width, label = "Misclassified")
    r2 = ax.bar(x + width/2, values_c, width, label = "Correct Classification")
    ax.set_ylabel('Count')
    ax.set_xlabel('Attack')
    ax.set_title('Classification by Attack')
    ax.set_xticks(x)
    ax.set_xticklabels(keys)
    ax.legend()
    ax.bar_label(r1, padding=3)
    ax.bar_label(r2, padding=3)
    plt.xticks(rotation=45, ha='right')
    fig.tight_layout()
#     plt.rcParams["figure.figsize"] = (30, 10)
#     plt.rcParams["xtick.labelsize"] = 10
    plt.show()
    
#https://stackoverflow.com/questions/42528921/how-to-prevent-overlapping-x-axis-labels-in-sns-countplot
def attack_report(y, y_p, a):
    att_dic_w, att_dic_c = calculate_classifications(y_p, y, a)
    plot_attack_classifications(att_dic_w, att_dic_c)


def f(row):
    if row['pred'] != row['label']:
        val = 1
    else: val = 0
    return val
    
def print_cm(y_test,y_pred_round): #show confusion matrix
    cm = confusion_matrix(y_test,y_pred_round)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benign', 'Anomaly'])
    disp = disp.plot(include_values=True, cmap = 'Blues')
    print(cm)
#     plt.rcParams["figure.figsize"] = (30, 10)
    plt.show()
    
def print_metrics(y_test,y_pred_round): #print basic metrics
    f1 = f1_score(y_test, y_pred_round, average='binary')
    acc = accuracy_score(y_test, y_pred_round)
    prec = precision_score(y_test, y_pred_round, average='binary')
    recall = recall_score(y_test, y_pred_round, average = 'binary')
    mcc = matthews_corrcoef(y_test, y_pred_round)
    print('accuracy: ',acc)
    print('f1: ', f1)
    print('precision: ', prec)
    print('recall: ', recall)
    print('mcc: ', mcc)
    
def training_report(train_model): #plot acc and loss vs epochs
    loss_vals = train_model.history['loss']
    epochs = range(1, len(loss_vals)+1)
#     plt.rcParams["figure.figsize"] = (30, 10)
    validation_loss = train_model.history['val_loss']
    plt.plot(epochs, loss_vals, label='Training Loss')
    plt.plot(epochs, validation_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    acc_vals = train_model.history['binary_accuracy']
    validation_acc = train_model.history['val_binary_accuracy']
    plt.plot(epochs, acc_vals, label='Training Accuracy')
    plt.plot(epochs, validation_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    
def test_report(y_test,y_pred_round):
    print_cm(y_test,y_pred_round)
    print_metrics(y_test,y_pred_round)

# %% [markdown]
# # Data Index
#
# - X_train, y_train - Training data from 3 datasets
# - X_test, y_test - Test data from 3 datasets
# - X_val, y_val - Validation data from 3 datasets
# - X_1, y_1 - 1 datasets, test phase 2 data

# %%
folder_rboa = 'rboa\\'
name_tail = '_rboa'
dnnfolder = 'E2_DNN\\'

NNs = [[20, 10, 10], [20, 20, 10, 5]]

# %%
X_train = np.load(folder_rboa+'X_train.npy')
X_val = np.load(folder_rboa+'X_val.npy')
y_train = np.load(folder_rboa+'y_train.npy')
y_val = np.load(folder_rboa+'y_val.npy')

# %%
batch_sz = 64
lr = 1e-3
esp = 10
rlrp = 5

dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail+".h5"
print(dnn_file)

weights = {0:1, 1:5}
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=rlrp, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
es = EarlyStopping(monitor='val_loss', patience=esp, mode='auto', restore_best_weights=False, min_delta=0.0001)
opt = Adam(learning_rate=lr)

DNN = Sequential()
for c in range(0,len(NNs[0])):
    if c == 0:
        DNN.add(Dense(NNs[0][0], input_dim=len(X_train[0]), activation='relu'))
        DNN.add(Dropout(0.5))
    else:
        DNN.add(Dense(NNs[0][c], activation='relu'))
        DNN.add(Dropout(0.5))
DNN.add(Dense(1, activation='sigmoid'))
DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
DNN.summary()
train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
DNN.save(dnnfolder+dnn_file)
training_report(train_DNN)
# Out:
# DNN_20_10_10_rboa.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                180
# _________________________________________________________________
# dropout (Dropout)            (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                210
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 511
# Trainable params: 511
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Will\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 113045/113045 [==============================] - 118s 1ms/step - loss: 0.6951 - binary_accuracy: 0.8419 - precision: 0.5765 - recall: 0.7889 - auc: 0.9000 - val_loss: 0.2776 - val_binary_accuracy: 0.9312 - val_precision: 0.8361 - val_recall: 0.8157 - val_auc: 0.9395 - auc: 0.
# Epoch 2/100
# 113045/113045 [==============================] - 117s 1ms/step - loss: 0.6433 - binary_accuracy: 0.8758 - precision: 0.6598 - recall: 0.7820 - auc: 0.9080 - val_loss: 0.2792 - val_binary_accuracy: 0.9307 - val_precision: 0.8330 - val_recall: 0.8171 - val_auc: 0.9364
# Epoch 3/100
# 113045/113045 [==============================] - 119s 1ms/step - loss: 0.6420 - binary_accuracy: 0.8775 - precision: 0.6644 - recall: 0.7834 - auc: 0.9086 - val_loss: 0.2771 - val_binary_accuracy: 0.9284 - val_precision: 0.8232 - val_recall: 0.8175 - val_auc: 0.9390
# Epoch 4/100
# 113045/113045 [==============================] - 112s 992us/step - loss: 0.6375 - binary_accuracy: 0.8803 - precision: 0.6728 - recall: 0.7815 - auc: 0.9098 - val_loss: 0.2652 - val_binary_accuracy: 0.9303 - val_precision: 0.8347 - val_recall: 0.8125 - val_auc: 0.9385
# Epoch 5/100
# 113045/113045 [==============================] - 117s 1ms/step - loss: 0.6554 - binary_accuracy: 0.8754 - precision: 0.6581 - recall: 0.7853 - auc: 0.9071 - val_loss: 0.3139 - val_binary_accuracy: 0.9300 - val_precision: 0.8295 - val_recall: 0.8182 - val_auc: 0.9310
# Epoch 6/100
# 113045/113045 [==============================] - 113s 997us/step - loss: 0.6625 - binary_accuracy: 0.8665 - precision: 0.6317 - recall: 0.7976 - auc: 0.9065 - val_loss: 0.3063 - val_binary_accuracy: 0.9300 - val_precision: 0.8293 - val_recall: 0.8185 - val_auc: 0.9320
# Epoch 7/100
# 113045/113045 [==============================] - 113s 1ms/step - loss: 0.6643 - binary_accuracy: 0.8656 - precision: 0.6292 - recall: 0.7991 - auc: 0.9069 - val_loss: 0.3233 - val_binary_accuracy: 0.9292 - val_precision: 0.8260 - val_recall: 0.8182 - val_auc: 0.9319
# Epoch 8/100
# 113045/113045 [==============================] - 116s 1ms/step - loss: 0.6575 - binary_accuracy: 0.8656 - precision: 0.6292 - recall: 0.7990 - auc: 0.9078 - val_loss: 0.2821 - val_binary_accuracy: 0.9298 - val_precision: 0.8294 - val_recall: 0.8171 - val_auc: 0.9376
# Epoch 9/100
# 113045/113045 [==============================] - 135s 1ms/step - loss: 0.6599 - binary_accuracy: 0.8662 - precision: 0.6305 - recall: 0.7992 - auc: 0.9075 - val_loss: 0.2972 - val_binary_accuracy: 0.9301 - val_precision: 0.8308 - val_recall: 0.8171 - val_auc: 0.9318 recall: 0.7 - ETA: 19s - loss: 0.6593 - binary_accuracy: 0.8656 - precision: 0.6289 - recall: 0.7 - ETA: 18s - loss: 0.6594 - binary_accurac - ETA: 17s - loss: 0.659 - ETA: 14s - loss: 0.6597 - binary_acc
# Epoch 10/100
# 113045/113045 [==============================] - 134s 1ms/step - loss: 0.6483 - binary_accuracy: 0.8694 - precision: 0.6378 - recall: 0.8032 - auc: 0.9096 - val_loss: 0.2954 - val_binary_accuracy: 0.9302 - val_precision: 0.8311 - val_recall: 0.8170 - val_auc: 0.9331
# Epoch 11/100
# 113045/113045 [==============================] - 126s 1ms/step - loss: 0.6492 - binary_accuracy: 0.8689 - precision: 0.6364 - recall: 0.8040 - auc: 0.9099 - val_loss: 0.2961 - val_binary_accuracy: 0.9297 - val_precision: 0.8283 - val_recall: 0.8183 - val_auc: 0.9333
# Epoch 12/100
# 113045/113045 [==============================] - 125s 1ms/step - loss: 0.6462 - binary_accuracy: 0.8689 - precision: 0.6364 - recall: 0.8040 - auc: 0.9099 - val_loss: 0.2921 - val_binary_accuracy: 0.9299 - val_precision: 0.8293 - val_recall: 0.8180 - val_auc: 0.9334
# Epoch 13/100
# 113045/113045 [==============================] - 127s 1ms/step - loss: 0.6488 - binary_accuracy: 0.8688 - precision: 0.6362 - recall: 0.8041 - auc: 0.9098 - val_loss: 0.2945 - val_binary_accuracy: 0.9299 - val_precision: 0.8291 - val_recall: 0.8180 - val_auc: 0.9334
# Epoch 14/100
# 113045/113045 [==============================] - 145s 1ms/step - loss: 0.6460 - binary_accuracy: 0.8690 - precision: 0.6369 - recall: 0.8028 - auc: 0.9100 - val_loss: 0.2838 - val_binary_accuracy: 0.9296 - val_precision: 0.8261 - val_recall: 0.8206 - val_auc: 0.938958 - binary_accuracy: 0.8699 - precision: 0.6387 - recal - ETA: 53s - loss: 0.6459 - binary_accuracy: 0.8699 - precision: 0.6387 - recall: 0.8038 - auc: 0 - ETA: 53s - loss: 0.6459 - binary_accuracy: 0.8698 - precision: 0.6384 - - ETA: 52s - loss: 0.6459 - b - ETA: 48s - loss: 0.6457 - binary_accuracy: 0.8698 - precision: 0.6386 - recall: 0.8038 - auc:  - ETA: 48s - loss: 0.6457 - binary_accuracy: 0.8698 - precision: 0.6386 - recall: 0.8038 - auc: - ETA: 48s - los - ETA: 40s - loss: 0.6458 - binary_accuracy: 0.8698 - precision: 0.6386 - recall: 0.803 - ETA: 39s - loss: 0.6458 - binary_accuracy: 0.8698 - precision: 0.6386 - r - ETA: 38s - loss: 0.6458 - binary_accuracy: 0.8698 - prec

# %%
batch_sz = 64
lr = 1e-4
esp = 10
rlrp = 5

dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail+".h5"
print(dnn_file)

weights = {0:1, 1:5}
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=rlrp, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
es = EarlyStopping(monitor='val_loss', patience=esp, mode='auto', restore_best_weights=False, min_delta=0.0001)
opt = Adam(learning_rate=lr)

DNN = Sequential()
for c in range(0,len(NNs[1])):
    if c == 0:
        DNN.add(Dense(NNs[1][0], input_dim=len(X_train[0]), activation='relu'))
        DNN.add(Dropout(0.5))
    else:
        DNN.add(Dense(NNs[1][c], activation='relu'))
        DNN.add(Dropout(0.5))
DNN.add(Dense(1, activation='sigmoid'))
DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
DNN.summary()
train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
DNN.save(dnnfolder+dnn_file)
training_report(train_DNN)
# Out:
# DNN_20_20_10_5_rboa.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 20)                180
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                210
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 871
# Trainable params: 871
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 113045/113045 [==============================] - 142s 1ms/step - loss: 0.8906 - binary_accuracy: 0.8448 - precision: 0.5978 - recall: 0.6848 - auc: 0.8351 - val_loss: 0.3714 - val_binary_accuracy: 0.9450 - val_precision: 0.9442 - val_recall: 0.7706 - val_auc: 0.8915
# Epoch 2/100
# 113045/113045 [==============================] - 141s 1ms/step - loss: 0.7679 - binary_accuracy: 0.9184 - precision: 0.8712 - recall: 0.6945 - auc: 0.8618 - val_loss: 0.3552 - val_binary_accuracy: 0.9472 - val_precision: 0.9541 - val_recall: 0.7732 - val_auc: 0.8954
# Epoch 3/100
# 113045/113045 [==============================] - 146s 1ms/step - loss: 0.7508 - binary_accuracy: 0.9174 - precision: 0.8617 - recall: 0.6995 - auc: 0.8750 - val_loss: 0.3385 - val_binary_accuracy: 0.9490 - val_precision: 0.9631 - val_recall: 0.7746 - val_auc: 0.9465
# Epoch 4/100
# 113045/113045 [==============================] - 139s 1ms/step - loss: 0.7396 - binary_accuracy: 0.9160 - precision: 0.8517 - recall: 0.7022 - auc: 0.8774 - val_loss: 0.3299 - val_binary_accuracy: 0.9487 - val_precision: 0.9651 - val_recall: 0.7712 - val_auc: 0.9436
# Epoch 5/100
# 113045/113045 [==============================] - 136s 1ms/step - loss: 0.7342 - binary_accuracy: 0.9153 - precision: 0.8454 - recall: 0.7054 - auc: 0.8796 - val_loss: 0.3330 - val_binary_accuracy: 0.9492 - val_precision: 0.9672 - val_recall: 0.7719 - val_auc: 0.9489
# Epoch 6/100
# 113045/113045 [==============================] - 148s 1ms/step - loss: 0.7314 - binary_accuracy: 0.9150 - precision: 0.8437 - recall: 0.7055 - auc: 0.8798 - val_loss: 0.3339 - val_binary_accuracy: 0.9494 - val_precision: 0.9686 - val_recall: 0.7718 - val_auc: 0.9499- ETA: 33s - ETA: 29s  - ETA: 3s - loss: 0.7313 - binary_accuracy: 0.9150 - precision: 0.8436 - reca - ETA: 3s - loss: 0.7314 - binary_accuracy: 0.915
# Epoch 7/100
# 113045/113045 [==============================] - 162s 1ms/step - loss: 0.7303 - binary_accuracy: 0.9150 - precision: 0.8433 - recall: 0.7061 - auc: 0.8798 - val_loss: 0.3329 - val_binary_accuracy: 0.9495 - val_precision: 0.9703 - val_recall: 0.7709 - val_auc: 0.9497 - ETA: 47s - loss: 0.7306 - binary_accuracy: 0.9149 -  - ETA: 45s -  - ETA: 40s - loss: 0.7306 - binary_accuracy: 0.9149 - precision: 0.8431 - recall: 0.7059 - - ETA: 40s - loss: 0.7307 - bina - ETA: 31s - loss: 0.73 - ETA - ETA: 22s - ETA: 13s - loss: 0.7300 - binary_accuracy: 0.9150 - precision: 0.8432 - recall: 0.7062 - auc - ETA: 12s - loss: 0.7301 - binary_accuracy: 0.9150 - pr - - ETA: 7s - loss: 0.7301 - binary_accuracy: 0.9150 - precision: 0.8434 - recall: 0.70 - ETA: 7s - loss: 0.7301 - binary_accuracy: 0.9150 - precision: 0.8434 - re - - ETA: 4s - loss: 0.7302 - binary_acc - ETA: 2s
# Epoch 8/100
# 113045/113045 [==============================] - 159s 1ms/step - loss: 0.7309 - binary_accuracy: 0.9153 - precision: 0.8448 - recall: 0.7062 - auc: 0.8796 - val_loss: 0.3301 - val_binary_accuracy: 0.9494 - val_precision: 0.9717 - val_recall: 0.7694 - val_auc: 0.9492ision: 0.8448 - recall: 0.70 - ETA: 14s - loss: 0.7308 - binary_accuracy: 0.9153 - precision: 0.8449 - recal - ETA:  - ETA: 4s - loss: 0.7309 - binary_acc - ETA: 0s - loss: 0.7309 - binary_accuracy: 0.9153 - precision: 0.8448 - recall: 0.7062 - auc: 0.87
# Epoch 9/100
# 113045/113045 [==============================] - 163s 1ms/step - loss: 0.7294 - binary_accuracy: 0.9151 - precision: 0.8437 - recall: 0.7063 - auc: 0.8802 - val_loss: 0.3323 - val_binary_accuracy: 0.9495 - val_precision: 0.9724 - val_recall: 0.7695 - val_auc: 0.9497
# Epoch 10/100
# 113045/113045 [==============================] - 160s 1ms/step - loss: 0.7267 - binary_accuracy: 0.9146 - precision: 0.8403 - recall: 0.7075 - auc: 0.8879 - val_loss: 0.3281 - val_binary_accuracy: 0.9494 - val_precision: 0.9710 - val_recall: 0.7702 - val_auc: 0.9501
# Epoch 11/100
# 113045/113045 [==============================] - 149s 1ms/step - loss: 0.7252 - binary_accuracy: 0.9144 - precision: 0.8394 - recall: 0.7073 - auc: 0.8886 - val_loss: 0.3272 - val_binary_accuracy: 0.9495 - val_precision: 0.9712 - val_recall: 0.7702 - val_auc: 0.9499 0.9143 - precision: 0.8390 - ETA: 11s - loss: 0.7254 - binary_accuracy: 0.9143 - precision: 0.8390 - re - ETA: 10s - loss: 0.7254 - binary_accura
# Epoch 12/100
# 113045/113045 [==============================] - 148s 1ms/step - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.8403 - recall: 0.7072 - auc: 0.8882 - val_loss: 0.3254 - val_binary_accuracy: 0.9495 - val_precision: 0.9710 - val_recall: 0.7703 - val_auc: 0.9450cy - ETA: 14s - loss: 0.7252 - binary_accuracy: 0.9146 - precision: 0.8405 - recall: 0.7070 -  - ETA: 14s - loss: 0.7251 - binary_accuracy: 0.9146 - precision: 0.8405 - recall: 0.7071 - a - ETA: 13s - loss: 0.7251 - binary_accuracy: 0.9146 - precision:  - ETA: 12s - loss: 0.7251 - binary_accuracy: 0.9146 - precision: 0.8406 - recall: 0.7072 - auc: 0.8 - ETA: 11s - loss: 0.7251 - - ETA: 9s - loss: 0.7250 - binary_accuracy: 0.9146 - precision: 0.8405 - recall: 0.7072 - auc: 0.88 - ETA: 9s - loss: 0.7250 - binary_accuracy: 0.9146 - precisio - ETA: 9s - loss: 0.7249 - binary_accuracy: 0.9146 - precision: 0.8406 - recall:  - ETA: 8s - loss: 0.7249 - binary_accuracy: 0.9 - ETA: 7s - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.8405  - ETA: 6s - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.840 - ETA: 6s - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.8405 - recall: 0.7072 - auc: 0. - ETA: 6s - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.8405  - ETA: 0s - loss: 0.7249 - binary_accuracy: 0.9146 - precision: 0.8403 - recall: 0.7072 - - ETA: 0s - loss: 0.7249 - binary_accuracy: 0.9146 - precision: 0.8403 - recall: 0.7072 - auc
# Epoch 13/100
# 113045/113045 [==============================] - 142s 1ms/step - loss: 0.7248 - binary_accuracy: 0.9146 - precision: 0.8400 - recall: 0.7078 - auc: 0.8893 - val_loss: 0.3248 - val_binary_accuracy: 0.9494 - val_precision: 0.9713 - val_recall: 0.7697 - val_auc: 0.9508_accuracy: 0.9146  - ETA: 1:02 - loss: 0.7242 - binary_accuracy: 0.9146 - precision: 0.840 - ETA: 1:02 - loss: 0.7242 - binary_accuracy: 0.9146  - ETA: 1:00 - loss: 0.7242 - binary_accuracy: 0.9146 - prec - ETA: 1:00 - ETA: 56s - loss: 0.7248 - binary_accu - ETA: - ETA: 46s - loss: 0.7256 - binary_accuracy: 0.9145 - precisio - ETA: 12s - loss: 0.7252 - binary_accuracy: 0.9145 - precision: 0.8397 - recal - E - ETA: 3s - loss: 0.7248 - binary - ETA: 1s - loss: 0.7248 - binary
# Epoch 14/100
# 113045/113045 [==============================] - 135s 1ms/step - loss: 0.7241 - binary_accuracy: 0.9143 - precision: 0.8391 - recall: 0.7073 - auc: 0.8892 - val_loss: 0.3244 - val_binary_accuracy: 0.9495 - val_precision: 0.9709 - val_recall: 0.7705 - val_auc: 0.9503
# Epoch 15/100
# 113045/113045 [==============================] - 136s 1ms/step - loss: 0.7253 - binary_accuracy: 0.9146 - precision: 0.8405 - recall: 0.7073 - auc: 0.8896 - val_loss: 0.3249 - val_binary_accuracy: 0.9494 - val_precision: 0.9710 - val_recall: 0.7699 - val_auc: 0.9502
# Epoch 16/100
# 113045/113045 [==============================] - 134s 1ms/step - loss: 0.7242 - binary_accuracy: 0.9145 - precision: 0.8396 - recall: 0.7074 - auc: 0.8896 - val_loss: 0.3254 - val_binary_accuracy: 0.9495 - val_precision: 0.9709 - val_recall: 0.7706 - val_auc: 0.9530
# Epoch 17/100
# 113045/113045 [==============================] - 139s 1ms/step - loss: 0.7243 - binary_accuracy: 0.9145 - precision: 0.8399 - recall: 0.7075 - auc: 0.8895 - val_loss: 0.3249 - val_binary_accuracy: 0.9495 - val_precision: 0.9709 - val_recall: 0.7706 - val_auc: 0.9507
# Epoch 18/100
# 113045/113045 [==============================] - 155s 1ms/step - loss: 0.7265 - binary_accuracy: 0.9146 - precision: 0.8403 - recall: 0.7072 - auc: 0.8891 - val_loss: 0.3248 - val_binary_accuracy: 0.9494 - val_precision: 0.9704 - val_recall: 0.7704 - val_auc: 0.9507
# Epoch 19/100
# 113045/113045 [==============================] - 143s 1ms/step - loss: 0.7245 - binary_accuracy: 0.9145 - precision: 0.8396 - recall: 0.7079 - auc: 0.8898 - val_loss: 0.3242 - val_binary_accuracy: 0.9495 - val_precision: 0.9712 - val_recall: 0.7701 - val_auc: 0.9510
# Epoch 20/100
# 113045/113045 [==============================] - 136s 1ms/step - loss: 0.7257 - binary_accuracy: 0.9145 - precision: 0.8400 - recall: 0.7073 - auc: 0.8895 - val_loss: 0.3253 - val_binary_accuracy: 0.9495 - val_precision: 0.9713 - val_recall: 0.7704 - val_auc: 0.9525
# Epoch 21/100
# 113045/113045 [==============================] - 156s 1ms/step - loss: 0.7244 - binary_accuracy: 0.9145 - precision: 0.8395 - recall: 0.7077 - auc: 0.8897 - val_loss: 0.3242 - val_binary_accuracy: 0.9495 - val_precision: 0.9712 - val_recall: 0.7701 - val_auc: 0.9509
# Epoch 22/100
# 113045/113045 [==============================] - 153s 1ms/step - loss: 0.7243 - binary_accuracy: 0.9145 - precision: 0.8395 - recall: 0.7078 - auc: 0.8897 - val_loss: 0.3246 - val_binary_accuracy: 0.9495 - val_precision: 0.9710 - val_recall: 0.7706 - val_auc: 0.9508
# Epoch 23/100
# 113045/113045 [==============================] - 171s 2ms/step - loss: 0.7245 - binary_accuracy: 0.9145 - precision: 0.8394 - recall: 0.7078 - auc: 0.8899 - val_loss: 0.3234 - val_binary_accuracy: 0.9495 - val_precision: 0.9704 - val_recall: 0.7708 - val_auc: 0.9528.8401 - recall: - ETA: 47s - loss: 0.7243 - binary_accuracy: 0.9146 - preci - ETA: 45s - loss: 0.7242 - binary_accuracy: 0.9146 - precision: 0.8401 - recall: 0.7079 - auc:  - ETA: - ETA: 30s - loss: 0.7243 - binary_accuracy: 0.9144 - precision: 0.8395 - reca - ETA: 29s - loss: 0.7243 - binary_accuracy: 0.9144 - precision: 0.8394 - recall: 0.7078 - auc: 0.88 - ETA: 29s - loss: 0.7243 - binary_accuracy: 0.9144 - precision: 0.8394 - recall: 0.707 - ETA: 23s - loss: 0.7242 - binary_accuracy: 0.9144 - precision: 0.8393 - recall: 0.7077 -  - ETA: 23s - loss: 0.7242 - binary_accuracy: 0.9144 - precision: 0.8393 - recall: 0.7 - ETA: 22s - loss: 0.7241 - binary_accuracy: 0.9145 - precision: 0.8394 - ETA - ETA: 17s - loss: 0.7241 - binary_accuracy: 0.9144 - precision: 0.8393 - recall: 0.7078 - auc: 0 - ETA: 17s - loss - ETA: 6s - loss: 0.7246 - binary_accurac - ETA: 5s - loss: 0.7245 - binary_acc - ETA: 4s - loss: 0.7246 - binary_accuracy: 0.9144 - prec
# Epoch 24/100
# 113045/113045 [==============================] - 164s 1ms/step - loss: 0.7245 - binary_accuracy: 0.9144 - precision: 0.8392 - recall: 0.7078 - auc: 0.8897 - val_loss: 0.3245 - val_binary_accuracy: 0.9494 - val_precision: 0.9707 - val_recall: 0.7704 - val_auc: 0.9510: 0.9144 - precision: 0.8393 - recall: 0.7078 - auc: 0. - ETA: 54s - loss: 0.7249 - binary_accuracy: 0.9 - ETA: 51s - loss: 0.7252 - binary_accuracy: 0.9144 - precision: 0.8392 - recall: 0. -  - ETA: 45s - loss: 0.7254 - binary_accuracy: 0 - ETA: 43s - loss: 0.7255 - binary_accuracy: 0.9143 - precision: 0.839 - ETA: 41s - loss: 0.7255 - binary_accuracy: 0.9143 - precision: 0.8391 - recall: - ETA: 40s - loss: 0.7254 - ET - ETA: 32s - loss: 0. - ETA: 20s - loss: 0.7249 - binary_accuracy: 0.9144 - precision: 0.8392 - - ETA: 19s - l - ETA: 14s - loss: 0.7245 - binary_accuracy: 0.9145 - precision: 0.8392 - recall:  - ETA: 13s - loss: 0.7245 - binary_accuracy: 0.9145 - precisi - ETA: 12s - loss: 0.7245 - b - ETA: 9s - loss: 0.7244 - binary_accuracy: 0.9145 - precision: 0.8393 - recall: 0.7078 - - ETA: 9s - loss: 0.7244 - binary_accuracy: 0.9145 - precision: 0.8393 -  - ETA: 6s - loss: 0.7243 - binary_accuracy: 0.9145 - precision: 0.8393 - recall: 0.70 - ETA: 6s - loss: 0.7243 - binary_accuracy: 0.9145 - prec - ETA
# Epoch 25/100
# 113045/113045 [==============================] - 172s 2ms/step - loss: 0.7256 - binary_accuracy: 0.9144 - precision: 0.8394 - recall: 0.7076 - auc: 0.8896 - val_loss: 0.3250 - val_binary_accuracy: 0.9494 - val_precision: 0.9708 - val_recall: 0.7703 - val_auc: 0.9528
# Epoch 26/100
# 113045/113045 [==============================] - 133s 1ms/step - loss: 0.7245 - binary_accuracy: 0.9145 - precision: 0.8396 - recall: 0.7079 - auc: 0.8898 - val_loss: 0.3243 - val_binary_accuracy: 0.9495 - val_precision: 0.9710 - val_recall: 0.7705 - val_auc: 0.9508
# Epoch 27/100
# 113045/113045 [==============================] - 139s 1ms/step - loss: 0.7255 - binary_accuracy: 0.9144 - precision: 0.8394 - recall: 0.7076 - auc: 0.8894 - val_loss: 0.3255 - val_binary_accuracy: 0.9496 - val_precision: 0.9708 - val_recall: 0.7709 - val_auc: 0.9531
# Epoch 28/100
# 113045/113045 [==============================] - 137s 1ms/step - loss: 0.7247 - binary_accuracy: 0.9144 - precision: 0.8392 - recall: 0.7077 - auc: 0.8898 - val_loss: 0.3246 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7706 - val_auc: 0.9512
# Epoch 29/100
# 113045/113045 [==============================] - 146s 1ms/step - loss: 0.7240 - binary_accuracy: 0.9139 - precision: 0.8368 - recall: 0.7078 - auc: 0.8901 - val_loss: 0.3245 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7708 - val_auc: 0.9457ETA: 48s - loss: 0.7234 - binary_accuracy: 0.9140 - precision: - ETA: 46s - loss: 0.7232 - ETA: 17s - loss: 0.7242 - binary_accuracy: 0.9139 - precision: 0.8367 - recall: 0.7077 - a - ETA: 5s - loss: - ETA: 3s - loss: 0.7240 - binary_accuracy: - ETA: 2s - loss:
# Epoch 30/100
# 113045/113045 [==============================] - 154s 1ms/step - loss: 0.7252 - binary_accuracy: 0.9142 - precision: 0.8378 - recall: 0.7083 - auc: 0.8903 - val_loss: 0.3244 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7706 - val_auc: 0.9455s: 0.7249 - binary_accuracy: 0.9142 - precision: 0.8374 - recall: 0.7082 - auc:
# Epoch 31/100
# 113045/113045 [==============================] - 138s 1ms/step - loss: 0.7234 - binary_accuracy: 0.9143 - precision: 0.8384 - recall: 0.7081 - auc: 0.8905 - val_loss: 0.3243 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7706 - val_auc: 0.9499
# Epoch 32/100
# 113045/113045 [==============================] - 130s 1ms/step - loss: 0.7232 - binary_accuracy: 0.9144 - precision: 0.8389 - recall: 0.7081 - auc: 0.8905 - val_loss: 0.3242 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7707 - val_auc: 0.9514
# Epoch 33/100
# 113045/113045 [==============================] - 131s 1ms/step - loss: 0.7242 - binary_accuracy: 0.9143 - precision: 0.8384 - recall: 0.7083 - auc: 0.8905 - val_loss: 0.3243 - val_binary_accuracy: 0.9495 - val_precision: 0.9707 - val_recall: 0.7706 - val_auc: 0.9427

# %% [markdown]
# # Test Set

# %%
X_1 = np.load(folder_rboa +'X_test.npy')
y_1 = np.load(folder_rboa +'y_test.npy')

print('-----------------------------------------\n\n')
dnn_file_1 = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail+".h5"
dnn_file_2 = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail+".h5"

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.rint(y_pred_1)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.rint(y_pred_2)


ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_1[ix]
print('Best Threshold=%f' % (best_thresh_1))
test_report(y_1 ,y_predr_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
test_report(y_1 ,y_predr_2)
# Out:
# -----------------------------------------
#
#
# DNN_20_10_10_rboa.h5  ROC AUC=0.984
# DNN_20_20_10_5_rboa.h5 ROC AUC=0.986
# Random: ROC AUC=0.500
# DNN_20_10_10_rboa.h5
#
# Best Threshold=0.706844
# [[1833448   81560]
#  [  20340  458412]]
# accuracy:  0.9574309872334738
# f1:  0.8999729072840142
# precision:  0.848955131006793
# recall:  0.9575145377982756
# mcc:  0.875609099302249
# DNN_20_20_10_5_rboa.h5
#
# Best Threshold=0.305094
# [[1903879   11129]
#  [  47476  431276]]
# accuracy:  0.9755175957489473
# f1:  0.9363789234625585
# precision:  0.9748443168589866
# recall:  0.9008338346367222
# mcc:  0.9223512300047555

# %% [markdown]
# # Full Test Set (Benign Equalized)

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)


DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.rint(y_pred_1)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.rint(y_pred_2)


ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_1))
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)
# Out:
# DNN_20_10_10_rboa.h5  ROC AUC=0.428
# DNN_20_20_10_5_rboa.h5 ROC AUC=0.566
# Random: ROC AUC=0.500
# DNN_20_10_10_rboa.h5
#
# Best Threshold=0.278902
# [[9587791  433058]
#  [1450957  807184]]
# accuracy:  0.8465659634872249
# f1:  0.4614611950721233
# precision:  0.6508278223120971
# recall:  0.3574550924853674
# mcc:  0.4039943462621405
# attack                    misclassification
# Bot                       1                     143097
# Brute Force -Web          0                          1
#                           1                       2142
# Brute Force -XSS          1                        927
# DDOS attack-HOIC          1                    1080858
# DDOS attack-LOIC-UDP      1                       2112
# DDoS attacks-LOIC-HTTP    0                       9652
#                           1                     297648
# DoS attacks-GoldenEye     0                      27723
# DoS attacks-Hulk          0                     432648
# DoS attacks-SlowHTTPTest  0                      14116
# DoS attacks-Slowloris     0                       9512
# FTP-BruteForce            0                      25933
# Infilteration             0                       2423
#                           1                     113938
# SQL Injection             1                        432
# SSH-Bruteforce            0                      16284
#                           1                      78695
# dtype: int64
# [16284, 78695]
# [9652, 297648]
# [1080858]
# [9512]
# [432648]
# [25933]
# [2423, 113938]
# [143097]
# [27723]
# [1, 2142]
# [14116]
# [432]
# [2112]
# [927]
# DNN_20_20_10_5_rboa.h5
#
# Best Threshold=0.307270
# [[9962000   58849]
#  [1719849  538292]]
# accuracy:  0.8551429718568058
# f1:  0.37704997264718515
# precision:  0.9014487365630564
# recall:  0.2383783829264869
# mcc:  0.4187619387599323
# attack                    misclassification
# Bot                       1                     143097
# Brute Force -Web          0                          1
#                           1                       2142
# Brute Force -XSS          1                        927
# DDOS attack-HOIC          1                    1080858
# DDOS attack-LOIC-UDP      1                       2112
# DDoS attacks-LOIC-HTTP    0                       9652
#                           1                     297648
# DoS attacks-GoldenEye     0                      27723
# DoS attacks-Hulk          0                     432648
# DoS attacks-SlowHTTPTest  0                      14116
# DoS attacks-Slowloris     0                       9512
# FTP-BruteForce            0                      25933
# Infilteration             0                       2423
#                           1                     113938
# SQL Injection             1                        432
# SSH-Bruteforce            0                      16284
#                           1                      78695
# dtype: int64
# [16284, 78695]
# [9652, 297648]
# [1080858]
# [9512]
# [432648]
# [25933]
# [2423, 113938]
# [143097]
# [27723]
# [1, 2142]
# [14116]
# [432]
# [2112]
# [927]

# %%
# Full AR Test set threshold

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)

#test set thresholds
bt1 = 0.56
bt2 = 0.57

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.where(y_pred_1 > bt1, 1, 0)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.where(y_pred_2 > bt2, 1, 0)

ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_1[ix]
print('Best Threshold=%f' % (best_thresh_1))
print('Using test set threshold', bt1)
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
print('Using test set threshold', bt2)
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)

# %%
X_1 = np.load(folder_rboa +'X_1.npy')
y_1 = np.load(folder_rboa +'y_1.npy')
a_1 = np.load(folder_rboa +'a_1.npy', allow_pickle=True)

#test set thresholds
bt1 = best_thresh_1
bt2 = best_thresh_2

DNN = load_model(dnnfolder+dnn_file_1)
y_pred_1 = DNN.predict(X_1)
y_predr_1 = np.where(y_pred_1 > bt1, 1, 0)
DNN = load_model(dnnfolder+dnn_file_2)
y_pred_2 = DNN.predict(X_1)
y_predr_2 = np.where(y_pred_2 > bt2, 1, 0)

ns_probs = [0 for _ in range(len(y_1))]
#calculate fpr, tpr & thesholds for oboa, rboa, random
fpr_1, tpr_1, thresholds_1 = roc_curve(y_1, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_1, y_pred_2)
fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_1, ns_probs)
#auc calculation
auc_1 = auc(fpr_1, tpr_1)    
auc_2 = auc(fpr_2, tpr_2)
auc_rand = auc(fpr_rand, tpr_rand)
print(dnn_file_1, ' ROC AUC=%.3f' % (auc_1))
print(dnn_file_2,'ROC AUC=%.3f' % (auc_2))
print('Random: ROC AUC=%.3f' % (auc_rand))
#plot data
plt.plot(fpr_1, tpr_1, marker='.', label=dnn_file_1)
plt.plot(fpr_2, tpr_2, marker='.', label=dnn_file_2)
plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
    
print(dnn_file_1, '\n')
J = tpr_1 - fpr_1
ix = argmax(J)
best_thresh_1 = thresholds_1[ix]
print('Best Threshold=%f' % (best_thresh_1))
print('Using test set threshold', bt1)
test_report(y_1 ,y_predr_1)
attack_report(y_1, y_predr_2, a_1)

print(dnn_file_2, '\n')
J = tpr_2 - fpr_2
ix = argmax(J)
best_thresh_2 = thresholds_2[ix]
print('Best Threshold=%f' % (best_thresh_2))
print('Using test set threshold', bt2)
test_report(y_1 ,y_predr_2)
attack_report(y_1, y_predr_2, a_1)

# %% [markdown]
# # AR Test Set (Benign Equalized)

# %%
X_1 = np.load(folder_rboa +'X_1_ar.npy')
y_1 = np.load(folder_rboa +'y_1_ar.npy')
a_1 = np.load(folder_rboa +'a_1_ar.npy', allow_pickle=True)



print('-----------------------------------------\n\n')
dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[0])+name_tail_rboa+".h5"
dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[1])+name_tail_rboa+".h5"

print(dnn_file_oboa, '\n')
DNN = load_model(dnnfolder+dnn_file_oboa)
y_pred_oboa = DNN.predict(X_1)
y_predr_oboa = np.rint(y_pred_oboa)
print(dnn_file_rboa, '\n')
DNN = load_model(dnnfolder+dnn_file_rboa)
y_pred_rboa = DNN.predict(X_1)
y_predr_rboa = np.rint(y_pred_rboa)

plot_roc_auc(y_1, y_1, y_pred_oboa, y_pred_rboa)

print('OBOA')
test_report(y_1 ,y_predr_oboa)
attack_report(y_1, y_predr_oboa, a_1)

print('RBOA')
test_report(y_1,y_predr_rboa)
attack_report(y_1, y_predr_rboa, a_1)
