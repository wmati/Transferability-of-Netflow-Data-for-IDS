# %% [markdown]
# # BE - Benign Equivalized

# %%
import numpy as np
from numpy import genfromtxt, argmax
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import pandas as pd
import re
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score, precision_score, recall_score, mean_absolute_error, matthews_corrcoef, roc_curve, auc,RocCurveDisplay

import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, GaussianNoise
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

pd.set_option('display.max_columns', None)
plt.rcParams["figure.figsize"] = (27, 10)
# plt.rcParams["xtick.labelsize"] = 10
sns.set_context('paper', font_scale=2)

# %%
def calculate_classifications(y_p, y, a): #calculate correct and wrong classifications by attack category
    y_p = y_p.flatten()
    df= pd.DataFrame({'pred':y_p, 'label':y, 'attack':a})
    df['misclassification'] = df.apply(f, axis=1)
    df = df[df['attack']!='Benign']
    attacks = df['attack'].unique()
    att_dic_w = dict((n, 0) for n in attacks)
    att_dic_c = att_dic_w.copy()
    count_series = df.groupby(['attack', 'misclassification']).size()
    print(count_series)
    for key in attacks:
        counts = count_series.get(key).to_list()
        print(counts)
        if count_series.get(key).get(0) == None:
            counts.insert(0,0)
        elif count_series.get(key).get(1) == None:
            counts.insert(1,0)
        att_dic_w[key] = counts[1]
        att_dic_c[key] = counts[0]
    return att_dic_w, att_dic_c

def plot_roc_auc(y_true_oboa, y_true_rboa, y_pred_oboa, y_pred_rboa):
    ns_probs = [0 for _ in range(len(y_true_oboa))]
    
    #calculate fpr, tpr & thesholds for oboa, rboa, random
    fpr_oboa, tpr_oboa, thresholds_oboa = roc_curve(y_true_oboa, y_pred_oboa)
    fpr_rboa, tpr_rboa, thresholds_rboa = roc_curve(y_true_rboa, y_pred_rboa)
    fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_true_oboa, ns_probs)
    
    #auc calculation
    auc_oboa = auc(fpr_oboa, tpr_oboa)    
    auc_rboa = auc(fpr_rboa, tpr_rboa)
    auc_rand = auc(fpr_rand, tpr_rand)
    print('OBOA: ROC AUC=%.3f' % (auc_oboa))
    print('RBOA: ROC AUC=%.3f' % (auc_rboa))
    print('Random: ROC AUC=%.3f' % (auc_rand))
    
    #plot data
    plt.plot(fpr_oboa, tpr_oboa, marker='.', label='OBOA')
    plt.plot(fpr_rboa, tpr_rboa, marker='.', label='RBOA')
    plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()

def plot_attack_classifications(att_dic_w, att_dic_c): #plot correct and wrong classifications by attack category
    width = 0.4
    keys = att_dic_w.keys()
    values_w = att_dic_w.values()
    values_c = att_dic_c.values()
    x = np.arange(len(keys))
    fig, ax = plt.subplots()
    r1 = ax.bar(x - width/2, values_w, width, label = "Misclassified")
    r2 = ax.bar(x + width/2, values_c, width, label = "Correct Classification")
    ax.set_ylabel('Count')
    ax.set_xlabel('Attack')
    ax.set_title('Classification by Attack')
    ax.set_xticks(x)
    ax.set_xticklabels(keys)
    ax.legend()
    ax.bar_label(r1, padding=3)
    ax.bar_label(r2, padding=3)
    plt.xticks(rotation=45, ha='right')
    fig.tight_layout()
#     plt.rcParams["figure.figsize"] = (30, 10)
#     plt.rcParams["xtick.labelsize"] = 10
    plt.show()
    
#https://stackoverflow.com/questions/42528921/how-to-prevent-overlapping-x-axis-labels-in-sns-countplot
def attack_report(y, y_p, a):
    att_dic_w, att_dic_c = calculate_classifications(y_p, y, a)
    plot_attack_classifications(att_dic_w, att_dic_c)


def f(row):
    if row['pred'] != row['label']:
        val = 1
    else: val = 0
    return val
    
def print_cm(y_test,y_pred_round): #show confusion matrix
    cm = confusion_matrix(y_test,y_pred_round)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benign', 'Anomaly'])
    disp = disp.plot(include_values=True, cmap = 'Blues')
    print(cm)
#     plt.rcParams["figure.figsize"] = (30, 10)
    plt.show()
    
def print_metrics(y_test,y_pred_round): #print basic metrics
    f1 = f1_score(y_test, y_pred_round, average='binary')
    acc = accuracy_score(y_test, y_pred_round)
    prec = precision_score(y_test, y_pred_round, average='binary')
    recall = recall_score(y_test, y_pred_round, average = 'binary')
    mcc = matthews_corrcoef(y_test, y_pred_round)
    print('accuracy: ',acc)
    print('f1: ', f1)
    print('precision: ', prec)
    print('recall: ', recall)
    print('mcc: ', mcc)
    
def training_report(train_model): #plot acc and loss vs epochs
    loss_vals = train_model.history['loss']
    epochs = range(1, len(loss_vals)+1)
#     plt.rcParams["figure.figsize"] = (30, 10)
    validation_loss = train_model.history['val_loss']
    plt.plot(epochs, loss_vals, label='Training Loss')
    plt.plot(epochs, validation_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    acc_vals = train_model.history['binary_accuracy']
    validation_acc = train_model.history['val_binary_accuracy']
    plt.plot(epochs, acc_vals, label='Training Accuracy')
    plt.plot(epochs, validation_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    
def test_report(y_test,y_pred_round):
    print_cm(y_test,y_pred_round)
    print_metrics(y_test,y_pred_round)

# %% [markdown]
# # Data Index
#
# - X_train, y_train - Training data from 3 datasets
# - X_test, y_test - Test data from 3 datasets
# - X_val, y_val - Validation data from 3 datasets
# - X_1, y_1 - 1 datasets, test phase 2 data

# %%
folder_oboa = 'oboa\\'
name_tail_oboa = '_oboa'
folder_rboa = 'rboa\\'
name_tail_rboa = '_rboa'
dnnfolder = 'savedDNN\\'

X_train = np.load(folder_oboa+'X_train.npy')
X_val = np.load(folder_oboa+'X_val.npy')
y_train = np.load(folder_oboa+'y_train.npy')
y_val = np.load(folder_oboa+'y_val.npy')

NNs = [[64, 64, 64, 64]]

# %%
for NN in range(0, len(NNs)):
    dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    print(dnn_file)
    
    weights = {0:1, 1:5}
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
    es = EarlyStopping(monitor='val_loss', patience=9, mode='auto', restore_best_weights=False, min_delta=0.0001)
    opt = Adam(learning_rate=1e-4)

    DNN = Sequential()
    for c in range(0,len(NNs[NN])):
        if c == 0:
            DNN.add(Dense(NNs[NN][0], input_dim=len(X_train[0]), activation='relu'))
            DNN.add(Dropout(0.5))
        else:
            DNN.add(Dense(NNs[NN][c], activation='relu'))
            DNN.add(Dropout(0.5))
    DNN.add(Dense(1, activation='sigmoid'))
    DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
    DNN.summary()
    train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
    DNN.save(dnnfolder+dnn_file)
    training_report(train_DNN)
# Out:
# DNN_64_64_64_64_oboa.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                576
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Will\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 56523/56523 [==============================] - 128s 2ms/step - loss: 0.5380 - binary_accuracy: 0.8296 - precision: 0.5422 - recall: 0.9488 - auc: 0.9379 - val_loss: 0.2216 - val_binary_accuracy: 0.8714 - val_precision: 0.6113 - val_recall: 0.9808 - val_auc: 0.9705
# Epoch 2/100
# 56523/56523 [==============================] - 126s 2ms/step - loss: 0.3730 - binary_accuracy: 0.8669 - precision: 0.6032 - recall: 0.9771 - auc: 0.9677 - val_loss: 0.2008 - val_binary_accuracy: 0.8812 - val_precision: 0.6308 - val_recall: 0.9789 - val_auc: 0.9786
# Epoch 3/100
# 56523/56523 [==============================] - 125s 2ms/step - loss: 0.3466 - binary_accuracy: 0.8781 - precision: 0.6253 - recall: 0.9738 - auc: 0.9729 - val_loss: 0.1877 - val_binary_accuracy: 0.8970 - val_precision: 0.6652 - val_recall: 0.9770 - val_auc: 0.9809
# Epoch 4/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3327 - binary_accuracy: 0.8860 - precision: 0.6418 - recall: 0.9729 - auc: 0.9754 - val_loss: 0.1810 - val_binary_accuracy: 0.8979 - val_precision: 0.6657 - val_recall: 0.9836 - val_auc: 0.9829
# Epoch 5/100
# 56523/56523 [==============================] - 125s 2ms/step - loss: 0.3252 - binary_accuracy: 0.8899 - precision: 0.6503 - recall: 0.9726 - auc: 0.9767 - val_loss: 0.1835 - val_binary_accuracy: 0.8987 - val_precision: 0.6673 - val_recall: 0.9842 - val_auc: 0.9832
# Epoch 6/100
# 56523/56523 [==============================] - 125s 2ms/step - loss: 0.3191 - binary_accuracy: 0.8937 - precision: 0.6588 - recall: 0.9715 - auc: 0.9776 - val_loss: 0.1743 - val_binary_accuracy: 0.9159 - val_precision: 0.7105 - val_recall: 0.9778 - val_auc: 0.9841
# Epoch 7/100
# 56523/56523 [==============================] - 126s 2ms/step - loss: 0.3145 - binary_accuracy: 0.8980 - precision: 0.6687 - recall: 0.9710 - auc: 0.9782 - val_loss: 0.1700 - val_binary_accuracy: 0.9132 - val_precision: 0.7020 - val_recall: 0.9832 - val_auc: 0.9845
# Epoch 8/100
# 56523/56523 [==============================] - 125s 2ms/step - loss: 0.3100 - binary_accuracy: 0.9002 - precision: 0.6736 - recall: 0.9717 - auc: 0.9786 - val_loss: 0.1670 - val_binary_accuracy: 0.9162 - val_precision: 0.7109 - val_recall: 0.9795 - val_auc: 0.9847
# Epoch 9/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3082 - binary_accuracy: 0.9014 - precision: 0.6765 - recall: 0.9712 - auc: 0.9789 - val_loss: 0.1661 - val_binary_accuracy: 0.9153 - val_precision: 0.7077 - val_recall: 0.9823 - val_auc: 0.9848
# Epoch 10/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3064 - binary_accuracy: 0.9022 - precision: 0.6783 - recall: 0.9716 - auc: 0.9791 - val_loss: 0.1655 - val_binary_accuracy: 0.9164 - val_precision: 0.7107 - val_recall: 0.9814 - val_auc: 0.9852
# Epoch 11/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3045 - binary_accuracy: 0.9027 - precision: 0.6795 - recall: 0.9717 - auc: 0.9793 - val_loss: 0.1637 - val_binary_accuracy: 0.9173 - val_precision: 0.7132 - val_recall: 0.9807 - val_auc: 0.9850
# Epoch 12/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3047 - binary_accuracy: 0.9033 - precision: 0.6809 - recall: 0.9716 - auc: 0.9794 - val_loss: 0.1644 - val_binary_accuracy: 0.9166 - val_precision: 0.7115 - val_recall: 0.9809 - val_auc: 0.9849
# Epoch 13/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3027 - binary_accuracy: 0.9034 - precision: 0.6812 - recall: 0.9716 - auc: 0.9795 - val_loss: 0.1649 - val_binary_accuracy: 0.9163 - val_precision: 0.7107 - val_recall: 0.9808 - val_auc: 0.9853
# Epoch 14/100
# 56523/56523 [==============================] - 129s 2ms/step - loss: 0.3029 - binary_accuracy: 0.9038 - precision: 0.6822 - recall: 0.9718 - auc: 0.9797 - val_loss: 0.1651 - val_binary_accuracy: 0.9165 - val_precision: 0.7111 - val_recall: 0.9809 - val_auc: 0.9852
# Epoch 15/100
# 56523/56523 [==============================] - 134s 2ms/step - loss: 0.3020 - binary_accuracy: 0.9040 - precision: 0.6826 - recall: 0.9720 - auc: 0.9797 - val_loss: 0.1665 - val_binary_accuracy: 0.9171 - val_precision: 0.7127 - val_recall: 0.9808 - val_auc: 0.9850
# Epoch 16/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3012 - binary_accuracy: 0.9041 - precision: 0.6828 - recall: 0.9720 - auc: 0.9798 - val_loss: 0.1610 - val_binary_accuracy: 0.9188 - val_precision: 0.7175 - val_recall: 0.9792 - val_auc: 0.9852
# Epoch 17/100
# 56523/56523 [==============================] - 132s 2ms/step - loss: 0.3027 - binary_accuracy: 0.9042 - precision: 0.6829 - recall: 0.9724 - auc: 0.9798 - val_loss: 0.1623 - val_binary_accuracy: 0.9171 - val_precision: 0.7129 - val_recall: 0.9804 - val_auc: 0.9852
# Epoch 18/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.3040 - binary_accuracy: 0.9040 - precision: 0.6825 - recall: 0.9724 - auc: 0.9798 - val_loss: 0.1616 - val_binary_accuracy: 0.9172 - val_precision: 0.7131 - val_recall: 0.9808 - val_auc: 0.9851
# Epoch 19/100
# 56523/56523 [==============================] - 130s 2ms/step - loss: 0.3013 - binary_accuracy: 0.9043 - precision: 0.6832 - recall: 0.9726 - auc: 0.9799 - val_loss: 0.1615 - val_binary_accuracy: 0.9165 - val_precision: 0.7112 - val_recall: 0.9809 - val_auc: 0.9854
# Epoch 20/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3010 - binary_accuracy: 0.9042 - precision: 0.6830 - recall: 0.9724 - auc: 0.9799 - val_loss: 0.1637 - val_binary_accuracy: 0.9160 - val_precision: 0.7098 - val_recall: 0.9816 - val_auc: 0.9852
# Epoch 21/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3024 - binary_accuracy: 0.9044 - precision: 0.6833 - recall: 0.9727 - auc: 0.9800 - val_loss: 0.1637 - val_binary_accuracy: 0.9171 - val_precision: 0.7127 - val_recall: 0.9808 - val_auc: 0.9854
# Epoch 22/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.2945 - binary_accuracy: 0.9062 - precision: 0.6875 - recall: 0.9729 - auc: 0.9806 - val_loss: 0.1630 - val_binary_accuracy: 0.9167 - val_precision: 0.7114 - val_recall: 0.9815 - val_auc: 0.9854
# Epoch 23/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.2925 - binary_accuracy: 0.9064 - precision: 0.6880 - recall: 0.9735 - auc: 0.9808 - val_loss: 0.1625 - val_binary_accuracy: 0.9168 - val_precision: 0.7118 - val_recall: 0.9815 - val_auc: 0.9854
# Epoch 24/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.2925 - binary_accuracy: 0.9064 - precision: 0.6880 - recall: 0.9736 - auc: 0.9808 - val_loss: 0.1622 - val_binary_accuracy: 0.9183 - val_precision: 0.7161 - val_recall: 0.9800 - val_auc: 0.9854
# Epoch 25/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.2920 - binary_accuracy: 0.9064 - precision: 0.6880 - recall: 0.9738 - auc: 0.9808 - val_loss: 0.1621 - val_binary_accuracy: 0.9171 - val_precision: 0.7127 - val_recall: 0.9810 - val_auc: 0.9854
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2b2eb7ead0e3> in <module>
#      30
#      31 for NN in range(0, len(NNs)):
# ---> 32     print(name_tail)
#      33     print(folder)
#      34     dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
#
# NameError: name 'name_tail' is not defined

# %%
X_train = np.load(folder_rboa+'X_train.npy')
X_val = np.load(folder_rboa+'X_val.npy')
y_train = np.load(folder_rboa+'y_train.npy')
y_val = np.load(folder_rboa+'y_val.npy')

for NN in range(0, len(NNs)):

    dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    print(dnn_file)
    
    weights = {0:1, 1:5}
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
    es = EarlyStopping(monitor='val_loss', patience=9, mode='auto', restore_best_weights=False, min_delta=0.0001)
    opt = Adam(learning_rate=1e-4)

    DNN = Sequential()
    for c in range(0,len(NNs[NN])):
        if c == 0:
            DNN.add(Dense(NNs[NN][0], input_dim=len(X_train[0]), activation='relu'))
            DNN.add(Dropout(0.5))
        else:
            DNN.add(Dense(NNs[NN][c], activation='relu'))
            DNN.add(Dropout(0.5))
    DNN.add(Dense(1, activation='sigmoid'))
    DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
    DNN.summary()
    train_DNN = DNN.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
    DNN.save(dnnfolder+dnn_file)
    training_report(train_DNN)
# Out:
# DNN_64_64_64_64_rboa.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                576
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 56523/56523 [==============================] - 127s 2ms/step - loss: 0.5519 - binary_accuracy: 0.8773 - precision: 0.6556 - recall: 0.8146 - auc: 0.9366 - val_loss: 0.1958 - val_binary_accuracy: 0.9499 - val_precision: 0.9346 - val_recall: 0.8059 - val_auc: 0.9629
# Epoch 2/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3930 - binary_accuracy: 0.9332 - precision: 0.8430 - recall: 0.8184 - auc: 0.9614 - val_loss: 0.1909 - val_binary_accuracy: 0.9527 - val_precision: 0.9371 - val_recall: 0.8184 - val_auc: 0.9673
# Epoch 3/100
# 56523/56523 [==============================] - 126s 2ms/step - loss: 0.3738 - binary_accuracy: 0.9415 - precision: 0.8810 - recall: 0.8181 - auc: 0.9638 - val_loss: 0.1888 - val_binary_accuracy: 0.9552 - val_precision: 0.9487 - val_recall: 0.8203 - val_auc: 0.9686
# Epoch 4/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3670 - binary_accuracy: 0.9460 - precision: 0.9035 - recall: 0.8171 - auc: 0.9646 - val_loss: 0.1890 - val_binary_accuracy: 0.9570 - val_precision: 0.9600 - val_recall: 0.8193 - val_auc: 0.9686
# Epoch 5/100
# 56523/56523 [==============================] - 136s 2ms/step - loss: 0.3636 - binary_accuracy: 0.9482 - precision: 0.9154 - recall: 0.8164 - auc: 0.9650 - val_loss: 0.1851 - val_binary_accuracy: 0.9589 - val_precision: 0.9710 - val_recall: 0.8189 - val_auc: 0.9696
# Epoch 6/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3592 - binary_accuracy: 0.9499 - precision: 0.9247 - recall: 0.8159 - auc: 0.9653 - val_loss: 0.1868 - val_binary_accuracy: 0.9592 - val_precision: 0.9721 - val_recall: 0.8195 - val_auc: 0.9699
# Epoch 7/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3577 - binary_accuracy: 0.9510 - precision: 0.9308 - recall: 0.8155 - auc: 0.9655 - val_loss: 0.1839 - val_binary_accuracy: 0.9595 - val_precision: 0.9745 - val_recall: 0.8191 - val_auc: 0.9692
# Epoch 8/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3577 - binary_accuracy: 0.9515 - precision: 0.9337 - recall: 0.8152 - auc: 0.9656 - val_loss: 0.1847 - val_binary_accuracy: 0.9595 - val_precision: 0.9744 - val_recall: 0.8192 - val_auc: 0.9693
# Epoch 9/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3567 - binary_accuracy: 0.9521 - precision: 0.9376 - recall: 0.8146 - auc: 0.9656 - val_loss: 0.1843 - val_binary_accuracy: 0.9597 - val_precision: 0.9747 - val_recall: 0.8196 - val_auc: 0.9700
# Epoch 10/100
# 56523/56523 [==============================] - 136s 2ms/step - loss: 0.3563 - binary_accuracy: 0.9523 - precision: 0.9391 - recall: 0.8145 - auc: 0.9657 - val_loss: 0.1840 - val_binary_accuracy: 0.9599 - val_precision: 0.9759 - val_recall: 0.8197 - val_auc: 0.9702
# Epoch 11/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3557 - binary_accuracy: 0.9528 - precision: 0.9421 - recall: 0.8143 - auc: 0.9657 - val_loss: 0.1852 - val_binary_accuracy: 0.9595 - val_precision: 0.9747 - val_recall: 0.8189 - val_auc: 0.9694
# Epoch 12/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3562 - binary_accuracy: 0.9530 - precision: 0.9428 - recall: 0.8143 - auc: 0.9657 - val_loss: 0.1834 - val_binary_accuracy: 0.9600 - val_precision: 0.9758 - val_recall: 0.8202 - val_auc: 0.9699
# Epoch 13/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3551 - binary_accuracy: 0.9533 - precision: 0.9448 - recall: 0.8142 - auc: 0.9658 - val_loss: 0.1835 - val_binary_accuracy: 0.9598 - val_precision: 0.9754 - val_recall: 0.8195 - val_auc: 0.9695
# Epoch 14/100
# 56523/56523 [==============================] - 134s 2ms/step - loss: 0.3547 - binary_accuracy: 0.9535 - precision: 0.9460 - recall: 0.8140 - auc: 0.9659 - val_loss: 0.1847 - val_binary_accuracy: 0.9599 - val_precision: 0.9754 - val_recall: 0.8203 - val_auc: 0.9696
# Epoch 15/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3532 - binary_accuracy: 0.9539 - precision: 0.9485 - recall: 0.8138 - auc: 0.9658 - val_loss: 0.1848 - val_binary_accuracy: 0.9599 - val_precision: 0.9766 - val_recall: 0.8193 - val_auc: 0.9696
# Epoch 16/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.3538 - binary_accuracy: 0.9539 - precision: 0.9485 - recall: 0.8138 - auc: 0.9659 - val_loss: 0.1835 - val_binary_accuracy: 0.9600 - val_precision: 0.9771 - val_recall: 0.8192 - val_auc: 0.9696
# Epoch 17/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3524 - binary_accuracy: 0.9541 - precision: 0.9493 - recall: 0.8139 - auc: 0.9659 - val_loss: 0.1827 - val_binary_accuracy: 0.9600 - val_precision: 0.9759 - val_recall: 0.8201 - val_auc: 0.9695
# Epoch 18/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.3538 - binary_accuracy: 0.9543 - precision: 0.9505 - recall: 0.8139 - auc: 0.9659 - val_loss: 0.1836 - val_binary_accuracy: 0.9599 - val_precision: 0.9754 - val_recall: 0.8199 - val_auc: 0.9696
# Epoch 19/100
# 56523/56523 [==============================] - 127s 2ms/step - loss: 0.3534 - binary_accuracy: 0.9543 - precision: 0.9502 - recall: 0.8139 - auc: 0.9660 - val_loss: 0.1839 - val_binary_accuracy: 0.9601 - val_precision: 0.9767 - val_recall: 0.8200 - val_auc: 0.9696
# Epoch 20/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3526 - binary_accuracy: 0.9543 - precision: 0.9503 - recall: 0.8140 - auc: 0.9659 - val_loss: 0.1840 - val_binary_accuracy: 0.9599 - val_precision: 0.9755 - val_recall: 0.8200 - val_auc: 0.9695
# Epoch 21/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3526 - binary_accuracy: 0.9541 - precision: 0.9492 - recall: 0.8138 - auc: 0.9659 - val_loss: 0.1836 - val_binary_accuracy: 0.9600 - val_precision: 0.9758 - val_recall: 0.8201 - val_auc: 0.9696
# Epoch 22/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3517 - binary_accuracy: 0.9542 - precision: 0.9497 - recall: 0.8140 - auc: 0.9661 - val_loss: 0.1835 - val_binary_accuracy: 0.9599 - val_precision: 0.9756 - val_recall: 0.8200 - val_auc: 0.9695
# Epoch 23/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3481 - binary_accuracy: 0.9549 - precision: 0.9528 - recall: 0.8147 - auc: 0.9665 - val_loss: 0.1828 - val_binary_accuracy: 0.9601 - val_precision: 0.9767 - val_recall: 0.8199 - val_auc: 0.9696
# Epoch 24/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3468 - binary_accuracy: 0.9551 - precision: 0.9545 - recall: 0.8145 - auc: 0.9665 - val_loss: 0.1822 - val_binary_accuracy: 0.9600 - val_precision: 0.9767 - val_recall: 0.8194 - val_auc: 0.9696
# Epoch 25/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3477 - binary_accuracy: 0.9551 - precision: 0.9542 - recall: 0.8147 - auc: 0.9666 - val_loss: 0.1821 - val_binary_accuracy: 0.9600 - val_precision: 0.9770 - val_recall: 0.8195 - val_auc: 0.9696
# Epoch 26/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3489 - binary_accuracy: 0.9552 - precision: 0.9548 - recall: 0.8147 - auc: 0.9666 - val_loss: 0.1824 - val_binary_accuracy: 0.9600 - val_precision: 0.9769 - val_recall: 0.8194 - val_auc: 0.9696
# Epoch 27/100
# 56523/56523 [==============================] - 136s 2ms/step - loss: 0.3470 - binary_accuracy: 0.9551 - precision: 0.9538 - recall: 0.8148 - auc: 0.9666 - val_loss: 0.1817 - val_binary_accuracy: 0.9602 - val_precision: 0.9775 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 28/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3467 - binary_accuracy: 0.9551 - precision: 0.9542 - recall: 0.8146 - auc: 0.9666 - val_loss: 0.1825 - val_binary_accuracy: 0.9601 - val_precision: 0.9769 - val_recall: 0.8200 - val_auc: 0.9696
# Epoch 29/100
# 56523/56523 [==============================] - 140s 2ms/step - loss: 0.3476 - binary_accuracy: 0.9551 - precision: 0.9543 - recall: 0.8147 - auc: 0.9666 - val_loss: 0.1817 - val_binary_accuracy: 0.9601 - val_precision: 0.9773 - val_recall: 0.8197 - val_auc: 0.9695
# Epoch 30/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3473 - binary_accuracy: 0.9551 - precision: 0.9541 - recall: 0.8149 - auc: 0.9667 - val_loss: 0.1817 - val_binary_accuracy: 0.9600 - val_precision: 0.9771 - val_recall: 0.8194 - val_auc: 0.9696
# Epoch 31/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.3460 - binary_accuracy: 0.9551 - precision: 0.9541 - recall: 0.8148 - auc: 0.9667 - val_loss: 0.1816 - val_binary_accuracy: 0.9601 - val_precision: 0.9766 - val_recall: 0.8199 - val_auc: 0.9696
# Epoch 32/100
# 56523/56523 [==============================] - 125s 2ms/step - loss: 0.3467 - binary_accuracy: 0.9552 - precision: 0.9548 - recall: 0.8148 - auc: 0.9667 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9775 - val_recall: 0.8197 - val_auc: 0.9696
# Epoch 33/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3471 - binary_accuracy: 0.9551 - precision: 0.9541 - recall: 0.8148 - auc: 0.9666 - val_loss: 0.1816 - val_binary_accuracy: 0.9602 - val_precision: 0.9773 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 34/100
# 56523/56523 [==============================] - 124s 2ms/step - loss: 0.3491 - binary_accuracy: 0.9551 - precision: 0.9543 - recall: 0.8146 - auc: 0.9666 - val_loss: 0.1818 - val_binary_accuracy: 0.9600 - val_precision: 0.9770 - val_recall: 0.8194 - val_auc: 0.9696
# Epoch 35/100
# 56523/56523 [==============================] - 123s 2ms/step - loss: 0.3464 - binary_accuracy: 0.9551 - precision: 0.9544 - recall: 0.8147 - auc: 0.9667 - val_loss: 0.1814 - val_binary_accuracy: 0.9601 - val_precision: 0.9774 - val_recall: 0.8192 - val_auc: 0.9696
# Epoch 36/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3472 - binary_accuracy: 0.9551 - precision: 0.9540 - recall: 0.8147 - auc: 0.9666 - val_loss: 0.1817 - val_binary_accuracy: 0.9601 - val_precision: 0.9770 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 37/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3467 - binary_accuracy: 0.9552 - precision: 0.9543 - recall: 0.8148 - auc: 0.9667 - val_loss: 0.1812 - val_binary_accuracy: 0.9600 - val_precision: 0.9773 - val_recall: 0.8193 - val_auc: 0.9696
# Epoch 38/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3466 - binary_accuracy: 0.9552 - precision: 0.9545 - recall: 0.8147 - auc: 0.9666 - val_loss: 0.1817 - val_binary_accuracy: 0.9601 - val_precision: 0.9771 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 39/100
# 56523/56523 [==============================] - 122s 2ms/step - loss: 0.3461 - binary_accuracy: 0.9551 - precision: 0.9538 - recall: 0.8148 - auc: 0.9666 - val_loss: 0.1820 - val_binary_accuracy: 0.9600 - val_precision: 0.9769 - val_recall: 0.8194 - val_auc: 0.9696
# Epoch 40/100
# 56523/56523 [==============================] - 135s 2ms/step - loss: 0.3467 - binary_accuracy: 0.9550 - precision: 0.9532 - recall: 0.8151 - auc: 0.9666 - val_loss: 0.1814 - val_binary_accuracy: 0.9601 - val_precision: 0.9772 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 41/100
# 56523/56523 [==============================] - 138s 2ms/step - loss: 0.3479 - binary_accuracy: 0.9552 - precision: 0.9543 - recall: 0.8148 - auc: 0.9666 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9774 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 42/100
# 56523/56523 [==============================] - 136s 2ms/step - loss: 0.3469 - binary_accuracy: 0.9551 - precision: 0.9542 - recall: 0.8148 - auc: 0.9666 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9776 - val_recall: 0.8197 - val_auc: 0.9696
# Epoch 43/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3473 - binary_accuracy: 0.9554 - precision: 0.9556 - recall: 0.8148 - auc: 0.9667 - val_loss: 0.1819 - val_binary_accuracy: 0.9601 - val_precision: 0.9773 - val_recall: 0.8197 - val_auc: 0.9696
# Epoch 44/100
# 56523/56523 [==============================] - 136s 2ms/step - loss: 0.3477 - binary_accuracy: 0.9553 - precision: 0.9550 - recall: 0.8148 - auc: 0.9668 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9774 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 45/100
# 56523/56523 [==============================] - 138s 2ms/step - loss: 0.3508 - binary_accuracy: 0.9552 - precision: 0.9546 - recall: 0.8150 - auc: 0.9667 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9774 - val_recall: 0.8198 - val_auc: 0.9696
# Epoch 46/100
# 56523/56523 [==============================] - 137s 2ms/step - loss: 0.3459 - binary_accuracy: 0.9552 - precision: 0.9544 - recall: 0.8150 - auc: 0.9668 - val_loss: 0.1818 - val_binary_accuracy: 0.9602 - val_precision: 0.9775 - val_recall: 0.8198 - val_auc: 0.9696

# %% [markdown]
# # Test Set

# %%
X_1_oboa = np.load(folder_oboa +'X_test.npy')
y_1_oboa = np.load(folder_oboa +'y_test.npy')

X_1_rboa = np.load(folder_rboa +'X_test.npy')
y_1_rboa = np.load(folder_rboa +'y_test.npy')

for NN in range(0, len(NNs)):
    dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    
    print(dnn_file_oboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_oboa)
    y_pred_oboa = DNN.predict(X_1_oboa)
    y_predr_oboa = np.rint(y_pred_oboa)
    test_report(y_1_oboa ,y_predr_oboa)
    
    print(dnn_file_rboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_rboa)
    y_pred_rboa = DNN.predict(X_1_rboa)
    y_predr_rboa = np.rint(y_pred_rboa)
    test_report(y_1_rboa ,y_predr_rboa)
    
    
    plot_roc_auc(y_1_oboa, y_1_rboa, y_pred_oboa, y_pred_rboa)
# Out:
# DNN_64_64_64_64_oboa.h5
#
# [[1463480  451530]
#  [  15017  463735]]
# accuracy:  0.8050988360580542
# f1:  0.6653218719714321
# precision:  0.5066674678918127
# recall:  0.9686330292092774
# mcc:  0.6032138332007163
# DNN_64_64_64_64_rboa.h5
#
# [[1906540    8468]
#  [  30333  448419]]
# accuracy:  0.9837907726756233
# f1:  0.9585299458444978
# precision:  0.9814658766828559
# recall:  0.9366415179466613
# mcc:  0.9488637505569918
# OBOA: ROC AUC=0.955
# RBOA: ROC AUC=0.985
# Random: ROC AUC=0.500

# %% [markdown]
# # AR Test Set (Benign Equalized)

# %%
X_1_oboa = np.load(folder_oboa +'X_1_ar.npy')
y_1_oboa = np.load(folder_oboa +'y_1_ar.npy')
a_1_oboa = np.load(folder_oboa +'a_1_ar.npy', allow_pickle=True)

X_1_rboa = np.load(folder_rboa +'X_1_ar.npy')
y_1_rboa = np.load(folder_rboa +'y_1_ar.npy')
a_1_rboa = np.load(folder_rboa +'a_1_ar.npy', allow_pickle=True)

for NN in range(0, len(NNs)):
    dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    
    print(dnn_file_oboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_oboa)
    y_pred_oboa = DNN.predict(X_1_oboa)
    y_predr_oboa = np.rint(y_pred_oboa)
    print(dnn_file_rboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_rboa)
    y_pred_rboa = DNN.predict(X_1_rboa)
    y_predr_rboa = np.rint(y_pred_rboa)
    
    plot_roc_auc(y_1_oboa, y_1_rboa, y_pred_oboa, y_pred_rboa)
    
    print('OBOA')
    test_report(y_1_oboa ,y_predr_oboa)
    attack_report(y_1_oboa, y_predr_oboa, a_1_oboa)
    
    print('OBOA')
    test_report(y_1_rboa ,y_predr_rboa)
    attack_report(y_1_rboa, y_predr_rboa, a_1_rboa)
# Out:
# DNN_64_64_64_64_oboa.h5
#
# DNN_64_64_64_64_rboa.h5
#
# OBOA: ROC AUC=0.829
# RBOA: ROC AUC=0.940
# Random: ROC AUC=0.500
# OBOA
# [[5976888 4043961]
#  [  81356  643418]]
# accuracy:  0.61609326885933
# f1:  0.23776785320001115
# precision:  0.13726604996096967
# recall:  0.8877498365007574
# mcc:  0.2448699786249727
# attack                    misclassification
# Brute Force -Web          0                       160
#                           1                      1983
# Brute Force -XSS          0                        19
#                           1                       908
# DoS attacks-GoldenEye     0                     27723
# DoS attacks-Hulk          0                    432648
# DoS attacks-SlowHTTPTest  0                     14116
# DoS attacks-Slowloris     0                      9512
# FTP-BruteForce            0                     25933
# Infilteration             0                     52384
#                           1                     63977
# SQL Injection             0                        60
#                           1                       372
# SSH-Bruteforce            0                     80863
#                           1                     14116
# dtype: int64
# [80863, 14116]
# [9512]
# [432648]
# [25933]
# [52384, 63977]
# [27723]
# [160, 1983]
# [14116]
# [60, 372]
# [19, 908]
# OBOA
# [[9975377   45472]
#  [ 117035  607739]]
# accuracy:  0.9848769122088128
# f1:  0.8820691081542978
# precision:  0.9303869653144237
# recall:  0.8385220772268321
# mcc:  0.8753610653678288
# attack                    misclassification
# Brute Force -Web          0                        29
#                           1                      2114
# Brute Force -XSS          0                        20
#                           1                       907
# DoS attacks-GoldenEye     0                     27723
# DoS attacks-Hulk          0                    432535
#                           1                       113
# DoS attacks-SlowHTTPTest  0                     14116
# DoS attacks-Slowloris     0                      7284
#                           1                      2228
# FTP-BruteForce            0                     25933
# Infilteration             0                      5150
#                           1                    111211
# SQL Injection             1                       432
# SSH-Bruteforce            0                     94949
#                           1                        30
# dtype: int64
# [94949, 30]
# [7284, 2228]
# [432535, 113]
# [25933]
# [5150, 111211]
# [27723]
# [29, 2114]
# [14116]
# [432]
# [20, 907]
