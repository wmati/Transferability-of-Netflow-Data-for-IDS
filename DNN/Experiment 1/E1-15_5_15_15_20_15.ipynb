# %% [markdown]
# # BE - Benign Equivalized

# %%
import numpy as np
from numpy import genfromtxt, argmax
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import pandas as pd
import re
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score, precision_score, recall_score, mean_absolute_error, matthews_corrcoef, roc_curve, auc,RocCurveDisplay

import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, GaussianNoise
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

pd.set_option('display.max_columns', None)
plt.rcParams["figure.figsize"] = (27, 10)
# plt.rcParams["xtick.labelsize"] = 10
sns.set_context('paper', font_scale=2)

# %%
def calculate_classifications(y_p, y, a): #calculate correct and wrong classifications by attack category
    y_p = y_p.flatten()
    df= pd.DataFrame({'pred':y_p, 'label':y, 'attack':a})
    df['misclassification'] = df.apply(f, axis=1)
    df = df[df['attack']!='Benign']
    attacks = df['attack'].unique()
    att_dic_w = dict((n, 0) for n in attacks)
    att_dic_c = att_dic_w.copy()
    count_series = df.groupby(['attack', 'misclassification']).size()
    print(count_series)
    for key in attacks:
        counts = count_series.get(key).to_list()
        print(counts)
        if count_series.get(key).get(0) == None:
            counts.insert(0,0)
        elif count_series.get(key).get(1) == None:
            counts.insert(1,0)
        att_dic_w[key] = counts[1]
        att_dic_c[key] = counts[0]
    return att_dic_w, att_dic_c

def plot_roc_auc(y_true_oboa, y_true_rboa, y_pred_oboa, y_pred_rboa):
    ns_probs = [0 for _ in range(len(y_true_oboa))]
    
    #calculate fpr, tpr & thesholds for oboa, rboa, random
    fpr_oboa, tpr_oboa, thresholds_oboa = roc_curve(y_true_oboa, y_pred_oboa)
    fpr_rboa, tpr_rboa, thresholds_rboa = roc_curve(y_true_rboa, y_pred_rboa)
    fpr_rand, tpr_rand, thresholds_rand = roc_curve(y_true_oboa, ns_probs)
    
    #auc calculation
    auc_oboa = auc(fpr_oboa, tpr_oboa)    
    auc_rboa = auc(fpr_rboa, tpr_rboa)
    auc_rand = auc(fpr_rand, tpr_rand)
    print('OBOA: ROC AUC=%.3f' % (auc_oboa))
    print('RBOA: ROC AUC=%.3f' % (auc_rboa))
    print('Random: ROC AUC=%.3f' % (auc_rand))
    
    #plot data
    plt.plot(fpr_oboa, tpr_oboa, marker='.', label='OBOA')
    plt.plot(fpr_rboa, tpr_rboa, marker='.', label='RBOA')
    plt.plot(fpr_rand, tpr_rand, linestyle='--', label='0.5')    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()

def plot_attack_classifications(att_dic_w_oboa, att_dic_c_oboa, att_dic_w_rboa, att_dic_c_rboa): #plot correct and wrong classifications by attack category
    width = 0.4
    keys = att_dic_w.keys()
    values_w = att_dic_w.values()
    values_c = att_dic_c.values()
    x = np.arange(len(keys))
    fig, ax = plt.subplots()
    r1 = ax.bar(x - width/2, values_w, width, label = "Misclassified")
    r2 = ax.bar(x + width/2, values_c, width, label = "Correct Classification")
    ax.set_ylabel('Count')
    ax.set_xlabel('Attack')
    ax.set_title('Classification by Attack')
    ax.set_xticks(x)
    ax.set_xticklabels(keys)
    ax.legend()
    ax.bar_label(r1, padding=3)
    ax.bar_label(r2, padding=3)
    plt.xticks(rotation=45, ha='right')
    fig.tight_layout()
    plt.show()
    
#https://stackoverflow.com/questions/42528921/how-to-prevent-overlapping-x-axis-labels-in-sns-countplot
def attack_report(y_oboa, y_p_oboa, a_oboa, y_rboa, y_p_rboa, a_rboa):
    att_dic_w_oboa, att_dic_c_oboa = calculate_classifications(y_p_oboa, y_oboa, a_oboa)
    att_dic_w_rboa, att_dic_c_rboa = calculate_classifications(y_p_rboa, y_rboa, a_rboa)
    plot_attack_classifications(att_dic_w_oboa, att_dic_c_oboa, att_dic_w_rboa, att_dic_c_rds33wboa)


def f(row):
    if row['pred'] != row['label']:
        val = 1
    else: val = 0
    return val
    
def print_cm(y_test,y_pred_round): #show confusion matrix
    cm = confusion_matrix(y_test,y_pred_round)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benign', 'Anomaly'])
    disp = disp.plot(include_values=True, cmap = 'Blues')
    print(cm)
#     plt.rcParams["figure.figsize"] = (30, 10)
    plt.show()
    
def print_metrics(y_test,y_pred_round): #print basic metrics
    f1 = f1_score(y_test, y_pred_round, average='binary')
    acc = accuracy_score(y_test, y_pred_round)
    prec = precision_score(y_test, y_pred_round, average='binary')
    recall = recall_score(y_test, y_pred_round, average = 'binary')
    mcc = matthews_corrcoef(y_test, y_pred_round)
    print('accuracy: ',acc)
    print('f1: ', f1)
    print('precision: ', prec)
    print('recall: ', recall)
    print('mcc: ', mcc)
    
def training_report(train_model): #plot acc and loss vs epochs
    loss_vals = train_model.history['loss']
    epochs = range(1, len(loss_vals)+1)
#     plt.rcParams["figure.figsize"] = (30, 10)
    validation_loss = train_model.history['val_loss']
    plt.plot(epochs, loss_vals, label='Training Loss')
    plt.plot(epochs, validation_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    acc_vals = train_model.history['binary_accuracy']
    validation_acc = train_model.history['val_binary_accuracy']
    plt.plot(epochs, acc_vals, label='Training Accuracy')
    plt.plot(epochs, validation_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    
def test_report(y_test,y_pred_round):
    print_cm(y_test,y_pred_round)
    print_metrics(y_test,y_pred_round)

# %% [markdown]
# # Data Index
#
# - X_train, y_train - Training data from 3 datasets
# - X_test, y_test - Test data from 3 datasets
# - X_val, y_val - Validation data from 3 datasets
# - X_1, y_1 - 1 datasets, test phase 2 data

# %%
folder_oboa = 'oboa\\'
name_tail_oboa = '_oboa'
folder_rboa = 'rboa\\'
name_tail_rboa = '_rboa'
dnnfolder = 'E1_DNN\\'

batch_sz = 64
epochsz = 100
lr = 1e-4

NNs = [[15, 5, 15, 15, 20, 15]]

# %%
X_train = np.load(folder_oboa+'X_train.npy')
X_val = np.load(folder_oboa+'X_val.npy')
y_train = np.load(folder_oboa+'y_train.npy')
y_val = np.load(folder_oboa+'y_val.npy')

for NN in range(0, len(NNs)):
    dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    print(dnn_file)
    
    weights = {0:1, 1:5}
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
    es = EarlyStopping(monitor='val_loss', patience=9, mode='auto', restore_best_weights=False, min_delta=0.0001)
    opt = Adam(learning_rate=lr)

    DNN = Sequential()
    for c in range(0,len(NNs[NN])):
        if c == 0:
            DNN.add(Dense(NNs[NN][0], input_dim=len(X_train[0]), activation='relu'))
            DNN.add(Dropout(0.5))
        else:
            DNN.add(Dense(NNs[NN][c], activation='relu'))
            DNN.add(Dropout(0.5))
    DNN.add(Dense(1, activation='sigmoid'))
    DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
    DNN.summary()
    train_DNN = DNN.fit(X_train, y_train, epochs=epochsz, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True, callbacks=[es, reduce_lr])
    DNN.save(dnnfolder+dnn_file)
    training_report(train_DNN)
# Out:
# DNN_15_5_15_15_20_15_oboa.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 15)                135
# _________________________________________________________________
# dropout (Dropout)            (None, 15)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 80
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                90
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15)                240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                320
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                315
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,196
# Trainable params: 1,196
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Will\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 113045/113045 [==============================] - 148s 1ms/step - loss: 1.0513 - binary_accuracy: 0.7563 - precision: 0.4264 - recall: 0.6337 - auc: 0.7682 - val_loss: 0.5007 - val_binary_accuracy: 0.8808 - val_precision: 0.8595 - val_recall: 0.4829 - val_auc: 0.8862
# Epoch 2/100
# 113045/113045 [==============================] - 154s 1ms/step - loss: 0.9598 - binary_accuracy: 0.8305 - precision: 0.5689 - recall: 0.6303 - auc: 0.8113 - val_loss: 0.4801 - val_binary_accuracy: 0.8883 - val_precision: 0.9340 - val_recall: 0.4750 - val_auc: 0.8977acy: 0.8305 - precision: 0.5690 - recall
# Epoch 3/100
# 113045/113045 [==============================] - 138s 1ms/step - loss: 0.9399 - binary_accuracy: 0.8303 - precision: 0.5659 - recall: 0.6499 - auc: 0.8225 - val_loss: 0.4613 - val_binary_accuracy: 0.8825 - val_precision: 0.9407 - val_recall: 0.4403 - val_auc: 0.9174
# Epoch 4/100
# 113045/113045 [==============================] - 144s 1ms/step - loss: 0.9065 - binary_accuracy: 0.8435 - precision: 0.5972 - recall: 0.6686 - auc: 0.8373 - val_loss: 0.4542 - val_binary_accuracy: 0.8816 - val_precision: 0.9465 - val_recall: 0.4324 - val_auc: 0.9364
# Epoch 5/100
# 113045/113045 [==============================] - 167s 1ms/step - loss: 0.8945 - binary_accuracy: 0.8474 - precision: 0.6077 - recall: 0.6682 - auc: 0.8405 - val_loss: 0.4406 - val_binary_accuracy: 0.8929 - val_precision: 0.9564 - val_recall: 0.4869 - val_auc: 0.9522
# Epoch 6/100
# 113045/113045 [==============================] - 164s 1ms/step - loss: 0.8709 - binary_accuracy: 0.8569 - precision: 0.6309 - recall: 0.6849 - auc: 0.8505 - val_loss: 0.4319 - val_binary_accuracy: 0.9111 - val_precision: 0.9677 - val_recall: 0.5748 - val_auc: 0.9578
# Epoch 7/100
# 113045/113045 [==============================] - 167s 1ms/step - loss: 0.8641 - binary_accuracy: 0.8581 - precision: 0.6341 - recall: 0.6863 - auc: 0.8517 - val_loss: 0.4332 - val_binary_accuracy: 0.9209 - val_precision: 0.9706 - val_recall: 0.6235 - val_auc: 0.9559
# Epoch 8/100
# 113045/113045 [==============================] - 163s 1ms/step - loss: 0.8615 - binary_accuracy: 0.8585 - precision: 0.6352 - recall: 0.6867 - auc: 0.8520 - val_loss: 0.4315 - val_binary_accuracy: 0.9217 - val_precision: 0.9687 - val_recall: 0.6288 - val_auc: 0.9576y: 0
# Epoch 9/100
# 113045/113045 [==============================] - 140s 1ms/step - loss: 0.8583 - binary_accuracy: 0.8578 - precision: 0.6326 - recall: 0.6893 - auc: 0.8534 - val_loss: 0.4307 - val_binary_accuracy: 0.9205 - val_precision: 0.9739 - val_recall: 0.6193 - val_auc: 0.9560
# Epoch 10/100
# 113045/113045 [==============================] - 140s 1ms/step - loss: 0.8571 - binary_accuracy: 0.8586 - precision: 0.6348 - recall: 0.6901 - auc: 0.8540 - val_loss: 0.4329 - val_binary_accuracy: 0.9102 - val_precision: 0.9692 - val_recall: 0.5689 - val_auc: 0.9552
# Epoch 11/100
# 113045/113045 [==============================] - 139s 1ms/step - loss: 0.8582 - binary_accuracy: 0.8578 - precision: 0.6327 - recall: 0.6893 - auc: 0.8536 - val_loss: 0.4355 - val_binary_accuracy: 0.9081 - val_precision: 0.9705 - val_recall: 0.5574 - val_auc: 0.9557
# Epoch 12/100
# 113045/113045 [==============================] - 138s 1ms/step - loss: 0.8559 - binary_accuracy: 0.8586 - precision: 0.6346 - recall: 0.6904 - auc: 0.8542 - val_loss: 0.4322 - val_binary_accuracy: 0.9191 - val_precision: 0.9747 - val_recall: 0.6113 - val_auc: 0.9557
# Epoch 13/100
# 113045/113045 [==============================] - 139s 1ms/step - loss: 0.8566 - binary_accuracy: 0.8595 - precision: 0.6376 - recall: 0.6892 - auc: 0.8539 - val_loss: 0.4378 - val_binary_accuracy: 0.9209 - val_precision: 0.9737 - val_recall: 0.6212 - val_auc: 0.9565
# Epoch 14/100
# 113045/113045 [==============================] - 138s 1ms/step - loss: 0.8558 - binary_accuracy: 0.8599 - precision: 0.6388 - recall: 0.6895 - auc: 0.8541 - val_loss: 0.4312 - val_binary_accuracy: 0.9204 - val_precision: 0.9742 - val_recall: 0.6182 - val_auc: 0.9557
# Epoch 15/100
# 113045/113045 [==============================] - 135s 1ms/step - loss: 0.8478 - binary_accuracy: 0.8600 - precision: 0.6374 - recall: 0.6953 - auc: 0.8564 - val_loss: 0.4191 - val_binary_accuracy: 0.9214 - val_precision: 0.9708 - val_recall: 0.6258 - val_auc: 0.9563
# Epoch 16/100
# 113045/113045 [==============================] - 152s 1ms/step - loss: 0.8478 - binary_accuracy: 0.8603 - precision: 0.6385 - recall: 0.6944 - auc: 0.8567 - val_loss: 0.4189 - val_binary_accuracy: 0.9210 - val_precision: 0.9718 - val_recall: 0.6232 - val_auc: 0.9593
# Epoch 17/100
# 113045/113045 [==============================] - 163s 1ms/step - loss: 0.8478 - binary_accuracy: 0.8602 - precision: 0.6385 - recall: 0.6942 - auc: 0.8567 - val_loss: 0.4208 - val_binary_accuracy: 0.9207 - val_precision: 0.9728 - val_recall: 0.6208 - val_auc: 0.9569
# Epoch 18/100
# 113045/113045 [==============================] - 160s 1ms/step - loss: 0.8469 - binary_accuracy: 0.8603 - precision: 0.6387 - recall: 0.6944 - auc: 0.8569 - val_loss: 0.4186 - val_binary_accuracy: 0.9215 - val_precision: 0.9729 - val_recall: 0.6248 - val_auc: 0.9569
# Epoch 19/100
# 113045/113045 [==============================] - 164s 1ms/step - loss: 0.8466 - binary_accuracy: 0.8604 - precision: 0.6389 - recall: 0.6949 - auc: 0.8573 - val_loss: 0.4180 - val_binary_accuracy: 0.9212 - val_precision: 0.9721 - val_recall: 0.6241 - val_auc: 0.9590
# Epoch 20/100
# 113045/113045 [==============================] - 151s 1ms/step - loss: 0.8462 - binary_accuracy: 0.8606 - precision: 0.6395 - recall: 0.6949 - auc: 0.8575 - val_loss: 0.4201 - val_binary_accuracy: 0.9202 - val_precision: 0.9720 - val_recall: 0.6186 - val_auc: 0.9595
# Epoch 21/100
# 113045/113045 [==============================] - 145s 1ms/step - loss: 0.8466 - binary_accuracy: 0.8603 - precision: 0.6387 - recall: 0.6942 - auc: 0.8571 - val_loss: 0.4215 - val_binary_accuracy: 0.9208 - val_precision: 0.9733 - val_recall: 0.6212 - val_auc: 0.9576
# Epoch 22/100
# 113045/113045 [==============================] - 159s 1ms/step - loss: 0.8466 - binary_accuracy: 0.8603 - precision: 0.6386 - recall: 0.6947 - auc: 0.8573 - val_loss: 0.4200 - val_binary_accuracy: 0.9211 - val_precision: 0.9737 - val_recall: 0.6220 - val_auc: 0.9593
# Epoch 23/100
# 113045/113045 [==============================] - 160s 1ms/step - loss: 0.8460 - binary_accuracy: 0.8603 - precision: 0.6386 - recall: 0.6945 - auc: 0.8572 - val_loss: 0.4203 - val_binary_accuracy: 0.9202 - val_precision: 0.9723 - val_recall: 0.6189 - val_auc: 0.9589
# Epoch 24/100
# 113045/113045 [==============================] - 157s 1ms/step - loss: 0.8463 - binary_accuracy: 0.8603 - precision: 0.6386 - recall: 0.6949 - auc: 0.8573 - val_loss: 0.4194 - val_binary_accuracy: 0.9212 - val_precision: 0.9733 - val_recall: 0.6230 - val_auc: 0.9577
# Epoch 25/100
# 113045/113045 [==============================] - 158s 1ms/step - loss: 0.8466 - binary_accuracy: 0.8600 - precision: 0.6373 - recall: 0.6957 - auc: 0.8581 - val_loss: 0.4194 - val_binary_accuracy: 0.9208 - val_precision: 0.9724 - val_recall: 0.6219 - val_auc: 0.9595
# Epoch 26/100
# 113045/113045 [==============================] - 157s 1ms/step - loss: 0.8446 - binary_accuracy: 0.8605 - precision: 0.6388 - recall: 0.6957 - auc: 0.8586 - val_loss: 0.4191 - val_binary_accuracy: 0.9207 - val_precision: 0.9725 - val_recall: 0.6209 - val_auc: 0.9591
# Epoch 27/100
# 113045/113045 [==============================] - 160s 1ms/step - loss: 0.8466 - binary_accuracy: 0.8600 - precision: 0.6377 - recall: 0.6947 - auc: 0.8580 - val_loss: 0.4193 - val_binary_accuracy: 0.9208 - val_precision: 0.9724 - val_recall: 0.6214 - val_auc: 0.9588
# Epoch 28/100
# 113045/113045 [==============================] - 152s 1ms/step - loss: 0.8464 - binary_accuracy: 0.8603 - precision: 0.6385 - recall: 0.6953 - auc: 0.8583 - val_loss: 0.4190 - val_binary_accuracy: 0.9209 - val_precision: 0.9724 - val_recall: 0.6223 - val_auc: 0.9570

# %%
X_train = np.load(folder_rboa+'X_train.npy')
X_val = np.load(folder_rboa+'X_val.npy')
y_train = np.load(folder_rboa+'y_train.npy')
y_val = np.load(folder_rboa+'y_val.npy')

for NN in range(0, len(NNs)):

    dnn_file = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    print(dnn_file)
    
    weights = {0:1, 1:5}
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=0, mode='auto', cooldown=1, min_lr=1e-9, min_delta=0.0001)
    es = EarlyStopping(monitor='val_loss', patience=9, mode='auto', restore_best_weights=False, min_delta=0.0001)
    opt = Adam(learning_rate=1e-4)

    DNN = Sequential()
    for c in range(0,len(NNs[NN])):
        if c == 0:
            DNN.add(Dense(NNs[NN][0], input_dim=len(X_train[0]), activation='relu'))
            DNN.add(Dropout(0.5))
        else:
            DNN.add(Dense(NNs[NN][c], activation='relu'))
            DNN.add(Dropout(0.5))
    DNN.add(Dense(1, activation='sigmoid'))
    DNN.compile(optimizer=opt, loss = 'binary_crossentropy', metrics=['BinaryAccuracy', 'Precision', 'Recall', 'AUC'])
    DNN.summary()
    train_DNN = DNN.fit(X_train, y_train, epochs=epochsz, batch_size=batch_sz, validation_data=(X_val, y_val), class_weight=weights, shuffle=True ,callbacks=[es, reduce_lr])
    DNN.save(dnnfolder+dnn_file)
    training_report(train_DNN)
# Out:
# DNN_15_5_15_15_20_15_rboa.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 15)                135
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 80
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                90
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 15)                240
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                320
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 15)                315
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 1,196
# Trainable params: 1,196
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 113045/113045 [==============================] - 169s 1ms/step - loss: 1.0155 - binary_accuracy: 0.8003 - precision: 0.5006 - recall: 0.6299 - auc: 0.7889 - val_loss: 0.4531 - val_binary_accuracy: 0.9328 - val_precision: 0.9279 - val_recall: 0.7200 - val_auc: 0.8858
# Epoch 2/100
# 113045/113045 [==============================] - 161s 1ms/step - loss: 0.8947 - binary_accuracy: 0.8880 - precision: 0.7476 - recall: 0.6641 - auc: 0.8379 - val_loss: 0.4172 - val_binary_accuracy: 0.9369 - val_precision: 0.9537 - val_recall: 0.7195 - val_auc: 0.8893
# Epoch 3/100
# 113045/113045 [==============================] - 162s 1ms/step - loss: 0.8655 - binary_accuracy: 0.8965 - precision: 0.7814 - recall: 0.6699 - auc: 0.8402 - val_loss: 0.4118 - val_binary_accuracy: 0.9396 - val_precision: 0.9721 - val_recall: 0.7187 - val_auc: 0.8845
# Epoch 4/100
# 113045/113045 [==============================] - 152s 1ms/step - loss: 0.8450 - binary_accuracy: 0.8992 - precision: 0.7903 - recall: 0.6751 - auc: 0.8458 - val_loss: 0.4047 - val_binary_accuracy: 0.9383 - val_precision: 0.9801 - val_recall: 0.7056 - val_auc: 0.8809
# Epoch 5/100
# 113045/113045 [==============================] - 135s 1ms/step - loss: 0.8382 - binary_accuracy: 0.9004 - precision: 0.7940 - recall: 0.6782 - auc: 0.8500 - val_loss: 0.4015 - val_binary_accuracy: 0.9329 - val_precision: 0.9846 - val_recall: 0.6752 - val_auc: 0.8842
# Epoch 6/100
# 113045/113045 [==============================] - 158s 1ms/step - loss: 0.8285 - binary_accuracy: 0.9013 - precision: 0.7974 - recall: 0.6793 - auc: 0.8584 - val_loss: 0.3923 - val_binary_accuracy: 0.9395 - val_precision: 0.9822 - val_recall: 0.7102 - val_auc: 0.9326
# Epoch 7/100
# 113045/113045 [==============================] - 157s 1ms/step - loss: 0.8261 - binary_accuracy: 0.8990 - precision: 0.7862 - recall: 0.6797 - auc: 0.8673 - val_loss: 0.3912 - val_binary_accuracy: 0.9398 - val_precision: 0.9811 - val_recall: 0.7129 - val_auc: 0.9352
# Epoch 8/100
# 113045/113045 [==============================] - 142s 1ms/step - loss: 0.8276 - binary_accuracy: 0.8990 - precision: 0.7861 - recall: 0.6802 - auc: 0.8680 - val_loss: 0.4001 - val_binary_accuracy: 0.9377 - val_precision: 0.9825 - val_recall: 0.7012 - val_auc: 0.9338
# Epoch 9/100
# 113045/113045 [==============================] - 144s 1ms/step - loss: 0.8259 - binary_accuracy: 0.8988 - precision: 0.7851 - recall: 0.6803 - auc: 0.8681 - val_loss: 0.3973 - val_binary_accuracy: 0.9329 - val_precision: 0.9845 - val_recall: 0.6751 - val_auc: 0.9361
# Epoch 10/100
# 113045/113045 [==============================] - 168s 1ms/step - loss: 0.8256 - binary_accuracy: 0.8993 - precision: 0.7872 - recall: 0.6807 - auc: 0.8671 - val_loss: 0.3967 - val_binary_accuracy: 0.9251 - val_precision: 0.9872 - val_recall: 0.6334 - val_auc: 0.9295 - auc: 0.86 - ETA: 1:00 - loss: 0.8267 - b
# Epoch 11/100
# 113045/113045 [==============================] - 167s 1ms/step - loss: 0.8268 - binary_accuracy: 0.9000 - precision: 0.7906 - recall: 0.6804 - auc: 0.8658 - val_loss: 0.4003 - val_binary_accuracy: 0.9303 - val_precision: 0.9846 - val_recall: 0.6621 - val_auc: 0.9360
# Epoch 12/100
# 113045/113045 [==============================] - 172s 2ms/step - loss: 0.8250 - binary_accuracy: 0.8990 - precision: 0.7856 - recall: 0.6809 - auc: 0.8682 - val_loss: 0.3993 - val_binary_accuracy: 0.9378 - val_precision: 0.9841 - val_recall: 0.7003 - val_auc: 0.935642s - loss: 0.8262 - binary_accuracy: 0.8990 - precision: 0.7860 - recall: 0.68 - E - ETA: 37s - loss: 0.8262 - binary_accuracy: 0.8991 - precision: 0.7862 - recall: 0.6805 - auc: 0.868 - ETA: 37s - loss: 0.8262 - binary_accuracy: 0.8991 - precision: 0.7862 - recall: 0.6805 - auc: 0. - ETA: 37s - loss: 0.8262 - binary_accuracy: 0.8990 - precis - ETA: 34s - loss: 0.8261 - binary_accuracy: 0.8990 - precision: 0.7861 - ETA: 33s - loss: 0.8259 - binary_accuracy: 0.8990 -  - ETA: 31s - loss: 0.8259
# Epoch 13/100
# 113045/113045 [==============================] - 170s 2ms/step - loss: 0.8208 - binary_accuracy: 0.8993 - precision: 0.7866 - recall: 0.6812 - auc: 0.8729 - val_loss: 0.3973 - val_binary_accuracy: 0.9325 - val_precision: 0.9877 - val_recall: 0.6709 - val_auc: 0.9367
# Epoch 14/100
# 113045/113045 [==============================] - 156s 1ms/step - loss: 0.8202 - binary_accuracy: 0.9000 - precision: 0.7894 - recall: 0.6817 - auc: 0.8734 - val_loss: 0.3965 - val_binary_accuracy: 0.9256 - val_precision: 0.9888 - val_recall: 0.6350 - val_auc: 0.9367
# Epoch 15/100
# 113045/113045 [==============================] - 170s 2ms/step - loss: 0.8213 - binary_accuracy: 0.9000 - precision: 0.7896 - recall: 0.6814 - auc: 0.8732 - val_loss: 0.3962 - val_binary_accuracy: 0.9329 - val_precision: 0.9874 - val_recall: 0.6729 - val_auc: 0.9363
# Epoch 16/100
# 113045/113045 [==============================] - 153s 1ms/step - loss: 0.8201 - binary_accuracy: 0.9002 - precision: 0.7905 - recall: 0.6815 - auc: 0.8729 - val_loss: 0.3961 - val_binary_accuracy: 0.9258 - val_precision: 0.9876 - val_recall: 0.6368 - val_auc: 0.9365

# %% [markdown]
# # Test Set

# %%
X_1_oboa = np.load(folder_oboa +'X_test.npy')
y_1_oboa = np.load(folder_oboa +'y_test.npy')

X_1_rboa = np.load(folder_rboa +'X_test.npy')
y_1_rboa = np.load(folder_rboa +'y_test.npy')

for NN in range(0, len(NNs)):
    dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    
    print(dnn_file_oboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_oboa)
    y_pred_oboa = DNN.predict(X_1_oboa)
    y_predr_oboa = np.rint(y_pred_oboa)
    print(dnn_file_rboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_rboa)
    y_pred_rboa = DNN.predict(X_1_rboa)
    y_predr_rboa = np.rint(y_pred_rboa)
    
    plot_roc_auc(y_1_oboa, y_1_rboa, y_pred_oboa, y_pred_rboa)
    
    print('OBOA')
    test_report(y_1_oboa ,y_predr_oboa)
    
    print('RBOA')
    test_report(y_1_rboa ,y_predr_rboa)
# Out:
# DNN_15_5_15_15_20_15_oboa.h5
#
# DNN_15_5_15_15_20_15_rboa.h5
#
# OBOA: ROC AUC=0.951
# RBOA: ROC AUC=0.942
# Random: ROC AUC=0.500
# OBOA
# [[1896791   18219]
#  [ 130657  348095]]
# accuracy:  0.9378066825356907
# f1:  0.8238291447058572
# precision:  0.9502639811746206
# recall:  0.7270883463672214
# mcc:  0.7972714916886432
# RBOA
# [[1911244    3764]
#  [  69623  409129]]
# accuracy:  0.9693423735044449
# f1:  0.9176948224910139
# precision:  0.9908838367325191
# recall:  0.8545739756700755
# mcc:  0.9027007643743346

# %% [markdown]
# # AR Test Set (Benign Equalized)

# %%
X_1_oboa = np.load(folder_oboa +'X_1_ar.npy')
y_1_oboa = np.load(folder_oboa +'y_1_ar.npy')
a_1_oboa = np.load(folder_oboa +'a_1_ar.npy', allow_pickle=True)

X_1_rboa = np.load(folder_rboa +'X_1_ar.npy')
y_1_rboa = np.load(folder_rboa +'y_1_ar.npy')
a_1_rboa = np.load(folder_rboa +'a_1_ar.npy', allow_pickle=True)

for NN in range(0, len(NNs)):
    dnn_file_oboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_oboa+".h5"
    dnn_file_rboa = "DNN_"+'_'.join(str(v) for v in NNs[NN])+name_tail_rboa+".h5"
    
    print(dnn_file_oboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_oboa)
    y_pred_oboa = DNN.predict(X_1_oboa)
    y_predr_oboa = np.rint(y_pred_oboa)
    print(dnn_file_rboa, '\n')
    DNN = load_model(dnnfolder+dnn_file_rboa)
    y_pred_rboa = DNN.predict(X_1_rboa)
    y_predr_rboa = np.rint(y_pred_rboa)
    
    plot_roc_auc(y_1_oboa, y_1_rboa, y_pred_oboa, y_pred_rboa)
    
    print('OBOA')
    test_report(y_1_oboa ,y_predr_oboa)
    
    print('RBOA')
    test_report(y_1_rboa ,y_predr_rboa)
    
    
    attack_report(y_1_oboa, y_predr_oboa, a_1_oboa, y_1_rboa, y_predr_rboa, a_1_rboa)
# Out:
# DNN_15_5_15_15_20_15_oboa.h5
#
# DNN_15_5_15_15_20_15_rboa.h5
#
# OBOA: ROC AUC=0.826
# RBOA: ROC AUC=0.839
# Random: ROC AUC=0.500
# OBOA
# [[9996420   24429]
#  [ 218125  506649]]
# accuracy:  0.9774276465868941
# f1:  0.8068609995445323
# precision:  0.9540011071819958
# recall:  0.6990441158209317
# mcc:  0.8060320112422613
# attack                    misclassification
# Brute Force -Web          0                         2
#                           1                      2141
# Brute Force -XSS          0                         2
#                           1                       925
# DoS attacks-GoldenEye     0                     26991
#                           1                       732
# DoS attacks-Hulk          0                    431440
#                           1                      1208
# DoS attacks-SlowHTTPTest  0                     14116
# DoS attacks-Slowloris     0                      5829
#                           1                      3683
# FTP-BruteForce            0                     25933
# Infilteration             0                       202
#                           1                    116159
# SQL Injection             1                       432
# SSH-Bruteforce            0                      2134
#                           1                     92845
# dtype: int64
# [2134, 92845]
# [5829, 3683]
# [431440, 1208]
# [25933]
# [202, 116159]
# [26991, 732]
# [2, 2141]
# [14116]
# [432]
# [2, 925]
# RBOA
# [[9999905   20944]
#  [ 199741  525033]]
# accuracy:  0.9794628008073613
# f1:  0.8263349782923641
# precision:  0.9616394097187244
# recall:  0.724409264129232
# mcc:  0.8249032417623134
# attack                    misclassification
# Brute Force -Web          0                        28
#                           1                      2115
# Brute Force -XSS          0                        19
#                           1                       908
# DoS attacks-GoldenEye     0                     27723
# DoS attacks-Hulk          0                    432506
#                           1                       142
# DoS attacks-SlowHTTPTest  0                     14116
# DoS attacks-Slowloris     0                      9512
# FTP-BruteForce            0                     25933
# Infilteration             0                      1050
#                           1                    115311
# SQL Injection             1                       432
# SSH-Bruteforce            0                     14146
#                           1                     80833
# dtype: int64
# [14146, 80833]
# [9512]
# [432506, 142]
# [25933]
# [1050, 115311]
# [27723]
# [28, 2115]
# [14116]
# [432]
# [19, 908]
